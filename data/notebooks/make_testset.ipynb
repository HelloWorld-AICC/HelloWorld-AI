# %% [markdown]
# # 평가용 쿼리 테스트셋 생성
# - 테스트셋을 만들기 위한 MongoDB 연결 및 데이터 확인

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://hwyewon:001101@helloworld-ai.fpdjl.mongodb.net/")
collection = client["HelloWorld-AI"]["foreigner_legalQA_v3"]

# %%
# Collection 구조 확인
print("Collection 이름:", collection.name)
print("Database 이름:", collection.database.name)
print("전체 문서 개수:", collection.count_documents({}))

# 샘플 문서 확인
sample_doc = collection.find_one()
if sample_doc:
    print("\n샘플 문서 구조:")
    for key in sample_doc.keys():
        print(f"- {key}: {type(sample_doc[key])}")
    print(f"\n샘플 문서 내용:\n{sample_doc}")
else:
    print("Collection이 비어있습니다.")
# Out:
# Collection 이름: foreigner_legalQA_v3
# Database 이름: HelloWorld-AI
# 전체 문서 개수: 867
#
# 샘플 문서 구조:
# - _id: <class 'bson.objectid.ObjectId'>
# - title: <class 'str'>
# - contents: <class 'str'>
# - url: <class 'str'>
# - Embedding: <class 'list'>
#
# 샘플 문서 내용:
# {'_id': ObjectId('689b3a86ffd306c1cd3c0679'), 'title': '보험가입/납부\n외국인 근로자 2023년 체류자격 변동으로 인하여 2023년분 보수총액 수정신고를 진행하였습니다.\n수정신고 후 변경된 보험료 조회는 어떻게 해야하나요?', 'contents': '고객님 안녕하십니까?\n근로복지공단 고객센터입니다.\n먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.\n\n※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.\n\n○ 문의하신 내용에 아래와 같이 답변 드립니다.\n\n일반적으로 민원서류가 보험료 고지작업 기준일(보통 매월15일) 이전에 처리되는 경우 고지작업 기준일이 속한 달의 월별보험료로 반영되며 이후 처리되는 경우 고지작업 기준일이 속한달의 다음 달 월별보험료로 반영하게 됩니다. 재산정 보험료는 고용산재토탈서비스를 통해 확인가능합니다.\n* 예: 11.16~12.15. 처리완료건은 12.18일 이후 재산정 내역 확인가능.\n \n▶ 고용산재보험토탈서비스[ https://total.comwel.or.kr ] (사업장으로 로그인)\n•정보조회 > 보험료정보 조회 >부과고지 보험료 조회(20209)\n•정보조회 > 보험료정보 조회 >개인별 부과고지보험료 조회(20210)\n\n사이버 상담은 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변 드리겠습니다. 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.\n\n※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.', 'url': 'https://www.comwel.or.kr/comwel/help/cyber/cyber_view.jsp?req_id=1024793&req_tp=0&page=1&start_dt=&end_dt=&req_tp=&type=title&key=%EC%99%B8%EA%B5%AD%EC%9D%B8', 'Embedding': [-0.02418765425682068, -0.04236791655421257, 0.00018649590492714196, 0.04057623818516731, 0.03211846575140953, 0.02455652877688408, -0.015664009377360344, 0.040997810661792755, -0.022264234721660614, 0.010941092856228352, 0.037704285234212875, -0.046478237956762314, 0.02974712662398815, -0.0024470898788422346, 0.007048145402222872, -0.030484875664114952, -0.02275167778134346, -0.011309968307614326, 0.024517007172107697, -0.003659107256680727, -0.0014796165050938725, -0.019734807312488556, 0.043000273406505585, 0.009142828173935413, -0.020498905330896378, 0.000894192315172404, 0.015176567249000072, 0.002766561694443226, 0.0028571337461471558, -0.013029188849031925, -0.025636805221438408, 0.01741616427898407, 0.00291312369517982, 0.015189741738140583, 0.0009501822059974074, -0.0038040224462747574, 0.024279873818159103, 0.024253524839878082, 0.036228783428668976, -5.6658936955500394e-05, -0.019313236698508263, 0.0550677552819252, 0.024688269942998886, 0.009794945828616619, 0.005444198381155729, -0.014860388822853565, 0.009202111512422562, -0.01670476421713829, -0.003731564851477742, 0.05195866525173187, -0.02127617783844471, 0.013582500629127026, 0.009590747766196728, -0.012027956545352936, 0.05351321026682854, 0.014438817277550697, 0.027270395308732986, 0.030168697237968445, -0.02313372679054737, -0.016770634800195694, 0.016362236812710762, -0.017376642674207687, 0.0022824134211987257, 0.005081910640001297, 0.030748357996344566, 0.06803107261657715, -0.03704557940363884, -0.0065376488491892815, -0.033462222665548325, 0.030221393331885338, -0.012126762419939041, 0.0011494405334815383, 0.00026492300094105303, -0.029009375721216202, 0.02221153862774372, 0.020617472007870674, 0.005378327798098326, -0.04958732798695564, 0.028034493327140808, 0.019207842648029327, -0.014886736869812012, -0.009841055609285831, 0.014834040775895119, -0.011059660464525223, -0.052380237728357315, 0.035148508846759796, -0.024701444432139397, -0.056385163217782974, -0.01907610148191452, -0.030774706974625587, -0.0013701068237423897, -0.04848070070147514, -0.02479366399347782, 0.002265945775434375, 0.018470093607902527, 0.030774706974625587, -0.010987202636897564, 0.021552832797169685, -0.017192205414175987, 0.03762524202466011, 0.025215234607458115, -0.0002943588769994676, -0.003952231258153915, 0.009709314443171024, 0.029088420793414116, 0.03717732056975365, 0.002412507776170969, -0.022303758189082146, -0.04895497113466263, 0.040049273520708084, -0.016256844624876976, 0.024899056181311607, -0.01108600851148367, 0.03153880313038826, 0.013187278062105179, 0.004801960662007332, -0.009432658553123474, 0.015887968242168427, 0.05032507702708244, -0.03873186558485031, 0.02001146413385868, -0.012027956545352936, 0.02256724052131176, -0.036966536194086075, -0.012719596736133099, 0.0005207887734286487, 0.007357737049460411, 0 ...

# %%
def search_documents_by_text(search_text, collection):
    """
    MongoDB collection에서 'text' 필드에 search_text를 포함하거나 일치하는 documents를 모두 찾아오는 함수
    
    Args:
        search_text (str): 검색할 텍스트
        collection: MongoDB collection 객체
        
    Returns:
        list: 매칭되는 문서들의 리스트
    """
    try:
        # 정확히 일치하는 문서와 부분 일치하는 문서를 모두 찾기
        # $regex를 사용하여 대소문자 구분 없이 검색
        query = {
            "text": {
                "$regex": search_text,
                "$options": "i"  # case insensitive
            }
        }
        
        # 검색 실행
        results = list(collection.find(query))
        
        print(f"검색어 '{search_text}'에 대한 결과: {len(results)}개 문서 발견")
        
        return results
        
    except Exception as e:
        print(f"검색 중 오류 발생: {e}")
        return []

# 사용 예시
# search_results = search_documents_by_text("비자", collection)
# for doc in search_results[:3]:  # 상위 3개만 출력
#     print(f"ID: {doc.get('_id', 'N/A')}")
#     print(f"Text: {doc.get('text', 'N/A')[:100]}...")  # 첫 100자만 출력
#     print("-" * 50)

# %%
import re
from typing import List, Optional, Dict, Any, Iterable, Tuple


def search_documents_advanced(search_text, collection, exact_match=False, limit=None, fields_to_return=None):
    """
    더 고급 검색 기능을 제공하는 함수
    
    Args:
        search_text (str): 검색할 텍스트
        collection: MongoDB collection 객체
        exact_match (bool): True면 정확히 일치하는 것만, False면 부분 일치도 포함
        limit (int): 반환할 최대 문서 수 (None이면 모든 결과)
        fields_to_return (list): 반환할 필드 목록 (None이면 모든 필드)
        
    Returns:
        list: 매칭되는 문서들의 리스트
    """
    try:
        # 쿼리 구성
        if exact_match:
            query = {"contents": search_text}
        else:
            query = {
                "contents": {
                    "$regex": search_text,
                    "$options": "i"
                }
            }
        
        # 검색 실행
        cursor = collection.find(query)
        
        # 필드 제한
        if fields_to_return:
            projection = {field: 1 for field in fields_to_return}
            cursor = collection.find(query, projection)
        
        # 결과 수 제한
        if limit:
            cursor = cursor.limit(limit)
        
        results = list(cursor)
        
        match_type = "정확 일치" if exact_match else "부분 일치"
        print(f"검색어 '{search_text}' ({match_type}): {len(results)}개 문서 발견")
        
        return results
        
    except Exception as e:
        print(f"검색 중 오류 발생: {e}")
        return []

# 키워드별 검색 함수
def search_by_keywords(keywords, collection, match_all=False):
    """
    여러 키워드로 검색하는 함수
    
    Args:
        keywords (list): 검색할 키워드 리스트
        collection: MongoDB collection 객체
        match_all (bool): True면 모든 키워드 포함, False면 하나라도 포함
        
    Returns:
        list: 매칭되는 문서들의 리스트
    """
    try:
        if match_all:
            # 모든 키워드를 포함하는 문서 찾기
            query = {
                "$and": [
                    {"contents": {"$regex": keyword, "$options": "i"}} 
                    for keyword in keywords
                ]
            }
        else:
            # 하나라도 포함하는 문서 찾기
            query = {
                "$or": [
                    {"contents": {"$regex": keyword, "$options": "i"}} 
                    for keyword in keywords
                ]
            }
        
        results = list(collection.find(query))
        
        match_type = "모든 키워드 포함" if match_all else "하나 이상 키워드 포함"
        print(f"키워드 {keywords} ({match_type}): {len(results)}개 문서 발견")
        
        return results
        
    except Exception as e:
        print(f"검색 중 오류 발생: {e}")
        return []

def search_by_keywords(
    collection,
    keywords: List[str],
    field: str = "text",
    require_all: bool = True,          # True: 모든 키워드 포함(AND), False: 하나 이상 포함(OR)
    case_insensitive: bool = True,     # 대소문자 무시
    limit: Optional[int] = None,
    projection: Optional[Iterable[str]] = None,  # 반환할 필드 리스트
    sort: Optional[Iterable[Tuple[str, int]]] = None  # 예: [("createdAt", -1)]
) -> List[Dict[str, Any]]:
    if not keywords:
        return []

    # 정규식 메타문자 이스케이프
    escaped = [re.escape(k) for k in keywords if isinstance(k, str) and k.strip()]
    if not escaped:
        return []

    regex_options = "i" if case_insensitive else ""
    conditions = [{field: {"$regex": kw, "$options": regex_options}} for kw in escaped]

    if len(conditions) == 1:
        query = conditions[0]
    else:
        query = {"$and": conditions} if require_all else {"$or": conditions}

    proj_dict = {f: 1 for f in projection} if projection else None

    cursor = collection.find(query, proj_dict) if proj_dict else collection.find(query)
    if sort:
        cursor = cursor.sort(list(sort))
    if limit:
        cursor = cursor.limit(int(limit))

    return list(cursor)

# %%
# 검색 함수 테스트 및 사용 예시

print("=== 기본 텍스트 검색 테스트 ===")
# 기본 검색 함수 테스트
search_results = search_documents_by_text("비자", collection)

if search_results:
    print(f"\n첫 번째 검색 결과:")
    first_doc = search_results[0]
    for key, value in first_doc.items():
        if key != '_id':
            print(f"{key}: {str(value)[:200]}...")  # 첫 200자만 출력
    print("-" * 80)

print("\n=== 고급 검색 테스트 ===")
# 정확 일치 검색
exact_results = search_documents_advanced("비자", collection, exact_match=True, limit=5)

# 부분 일치 검색 (상위 10개만)
partial_results = search_documents_advanced("비자", collection, exact_match=False, limit=10)

# 특정 필드만 반환
limited_fields = search_documents_advanced("비자", collection, limit=5, fields_to_return=['text'])
# Out:
# === 기본 텍스트 검색 테스트 ===
# 검색어 '비자'에 대한 결과: 0개 문서 발견
#
# === 고급 검색 테스트 ===
# 검색어 '비자' (정확 일치): 0개 문서 발견
# 검색어 '비자' (부분 일치): 10개 문서 발견
# 검색어 '비자' (부분 일치): 5개 문서 발견

# %%
# 모든 키워드를 포함(AND)
docs = search_by_keywords(collection, ["답변"], field="contents", require_all=True)

# # 하나 이상 포함(OR)
# docs_any = search_by_keywords(collection, ["방문취업 동포", "H-2"], field="contents", require_all=False, projection=["_id", "contents"])

# %%
print(len(docs))
for doc in docs:
    print(f"ID: {doc.get('_id', 'N/A')}")
    print(f"contents: {doc.get('contents', 'N/A')}")  # 첫 100자만 출력
    print("-" * 50)
# Out:
# 289
# ID: 689b3a86ffd306c1cd3c0679
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ○ 문의하신 내용에 아래와 같이 답변 드립니다.
#
# 일반적으로 민원서류가 보험료 고지작업 기준일(보통 매월15일) 이전에 처리되는 경우 고지작업 기준일이 속한 달의 월별보험료로 반영되며 이후 처리되는 경우 고지작업 기준일이 속한달의 다음 달 월별보험료로 반영하게 됩니다. 재산정 보험료는 고용산재토탈서비스를 통해 확인가능합니다.
# * 예: 11.16~12.15. 처리완료건은 12.18일 이후 재산정 내역 확인가능.
#
# ▶ 고용산재보험토탈서비스[ https://total.comwel.or.kr ] (사업장으로 로그인)
# •정보조회 > 보험료정보 조회 >부과고지 보험료 조회(20209)
# •정보조회 > 보험료정보 조회 >개인별 부과고지보험료 조회(20210)
#
# 사이버 상담은 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변 드리겠습니다. 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c067a
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ○ 문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인 체류코드가 당연에서 임의로 변경된 경우 상실신고대상이며 임의(선택)가입자가 고용보험가입을 희망하는 경우 「외국인 고용보험 가입신청서」와 [피보험자 취득신고서]를 제출하여 가입합니다.
# ※ 고용보험은 가입신청서를 제출한 날의 다음날부터 적용되고 소급취득은 불가.
#
# 사이버 상담은 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변 드리겠습니다. 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c067b
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# 문의하신 내용에 아래와 같이 답변 드립니다.
#
# 고용보험법 제10조제5호 및 같은 법 시행령 제3조제2항제1호에 따르면 외국인근로자는 원칙적으로 고용보험 적용을 제외하되, 출입국관리법시행령 제23조제1항에 따른 취업활동을 할 수 있는 체류자격을 가진 자에 한하여 예외적으로 신청에 의하여 적용할 수 있다고 규정하고 있습니다.
#
# 방문취업(H-2)[ 고용안정직업능력개발 (당연가입), 실업급여(임의가입) ]: 산재보험은 외국인근로자도 당연가입이며 고용보험은 고용안정·직업능력보험만 적용대상으로 실업급여 가입을 원하는 경우 [외국인고용보험가입신청서]를 별도로 제출하여 가입하여야 합니다. 안타깝게도 실업급여 보험은 임의가입으로 가입신청서를 제출한 날의 다음날부터 적용되고 소급적용은 불가합니다.
#
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
# 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변 드리겠습니다. 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c067c
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 현장실습 범위는 고교(일반계고, 직업계고), 대학(전문대학, 대학) 등 초·중등교육법, 고등교육법 상 학교에서 직접 시행하거나 참여*하는 모든 국내 현장실습이 해당됩니다.
# 외국인유학생도 산재보험 가입가능 할것으로 보이나 정확한 판단은 관할지사로 다시한번 확인해보시기바랍니다.
#
# ※ 사업장의 정보가 기재되어있지 않아 부득이 담당자 연락처 확인 가능한 경로로 안내드립니다.
# ▶공단 홈페이지 : [공단소개> 조직안내> 지역본부 및 지사 연락처 검색 바로가기 ]
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다. 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하시고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c067d
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 산재보험은 외국인근로자의 체류자격과 무관하게 산재보험은 당연가입 대상이므로 근로 공백이 없는 경우 취득신고를 유지 가능하며(취득상실 불필요). 고용보험도 일반적으로 기간 연장은 취득,상실하지 않고 유지합니다. 다만 고용보험은 유효한 체류자격이 있을 때만 가입가능하므로 근로공백이 있거나 허가기간 또는 근로공백이 있는 경우 종료일로 상실하고 다시 취득하는 것이 원칙이나 근로의 단절이 없는 경우 담당자와 먼저 상의 하시고 처리하시길 바랍니다.
#
# ※ 사업장의 정보가 기재되어있지 않아 부득이 담당자 연락처 확인 가능한 경로로 안내드립니다.
# ▶공단 홈페이지 : [공단소개> 조직안내> 지역본부 및 지사 연락처 검색 바로가기 ]
#
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다. 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하시고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c067e
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 네, 맞습니다.
# 체류자격이 기업투자(D-7)인 외국인의 국적이 중국인 경우 사회보장협정에 따른 적용제외 대상이며, 특정활동(E-7) 외국인 근로자는 고용보험 임의가입대상으로 고용보험의 가입을 원하는 경우「외국인 고용보험 가입신청서」를 체출하여 가입가능합니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c067f
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 공단의 업무와 관련해 불편드린 점 사과드리며, 문의내용에 답변 드립니다
#
# 문의하신 [고용보험법] 개정에 따른 고용허가대상 외국인 근로자 고용보험 적용안내에 대한 안내문은
# 21.1.1부터 「외국인근로자의 고용등에 관할 법률」(약칭: 외국인고용법)의 적용을 받는 외국인근로자들중 체류자격이 방문취업(H-2)또는 비전문취업 비전문취업(E-9) 비자로 근무중인자는 사업 또는 사업장의 상시근로자수에 따라 단계적으로 고용보험(고용안정.직업능력개발사업)당연적용대상으로 변경되었으며 상용직일 경우 취득신고, 일용직일 경우 근로내용확인신고를 제출해야 함을 안내한 것입니다.
#
# 따라서 외국인고용법에 따라 해당 사업장(건설현장)등에 외국인 일용직을 채용가능 여부는 근로복지 공단의 업무가 아닌 고용노동부에서 판단하고 승인하는 부분으로 이는 고용노동부로 문의하여 판단 받으셔야 합니다. 문의사항에 만족스런 답변 드리지 못해 죄송합니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0680
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 당연적용 대상 외국인체류자격의 경우 근로를 개시한 날을 취득일로 적용하며, 내국인 근로자와 동일하게 사유가 발생한 날이 속하는 달의 다음달 15일까지 ‘피보험 자격취득신고서’ 제출하여야 합니다.
# ＊ [고용보험법] 시행령 제7조(피보험자격의 취득 또는 상실 신고 등), 시행규칙 제5조(피보험자격의 취득·상실신고 등)
#
# 다만 법무부 출입국관리사무에서 외국인 등록이 늦어져 외국인등록번호가 발번되지 않는 상태에서는 취득,상실신고를 할수 없으므로 외국인등록증이 법정 신고기한 보다 늦게 발급되는 경우, 이후 발급되는 즉시 공단으로 신고하셔야 합니다.
# 일반적으로 외국인 등록번호 지연발급에 따른 지연신고는 과태료 불이행 대상이나 외국인 등록번호 발급이후 기간지연등 사실관계에 따라 업무담당자의 판단을 필요로 하므로 담당자에게 사업장 정보등을 제공하시고 문의하시길 안내드립니다.
#
# ※ 사업장의 정보(사업장관리번호등)가 기재되어있지 않아 부득이 담당자 연락처 확인 가능한 경로 안내드립니다.
# ▶ 근로복지공단 홈페이지 :
# ☞ [공단소개> 조직안내> 지역본부 및 지사 연락처 검색 바로가기 ]
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0681
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 임의가입 대상 외국인 근로자은 고용보험은 선택하여 가입이 가능하며 고용보험 가입을 원하는 경우 「외국인 고용보험 가입·탈퇴 신청서」를 접수하여야 가입합니다.
# 단, 고용안정직업능력개발 (당연가입), 실업급여(임의가입) : 비전문취업(E-9), 방문취업(H-2) 체류자격은 취득신고서 제출대상이며 실업급여 가입을 원할 경우 「외국인 고용보험 가입·탈퇴 신청서」를 추가 제출하여 가입
# 단,65세 이후 취득 근로자는 실업급여 가입대상 아님
# -일용근로자는 65세 전후 사이에 10일 이상의 공백(휴일 등 포함)이 있는 경우 실업급여 제외
#
# 또한 산재보험은 체류자격과 무관하게 당연가입이므로 산재보험의 대한 취득신고는 하여야하며 해당사업장이 건설업(자진신고)인 경우 산재보험 취득신고는 하지 않으나 근로자 보수를 산재보수총액에 포함하여 확정정산하셔야 합니다.
#
# 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 개별사례에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다. 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0682
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인근로자의 경우 체류자격과 무관하게 산재보험은 당연가입 대상이나 고용보험 출입국관리법상의 체류자격에 따라 당연, 임의, 미가입, 상호주의로 구분하여 적용합니다. 기업투자(D-8)체류자격은 [상호주의] 적용으로써 국가 간 상호주의 원칙에 따라 법을 적용합니다.
# ★ (상호주의) : 국가 간 상호주의 원칙에 따라 법적용(해당 외국인의 본국법이 대한민국 국민에게 보험을 적용하지 아니하는 경우 제외)
#
# 체류자격이 기업투자(D-8)인 외국인의 국적이 일본인 경우 본국법이 대한민국 국민에게 보험을 적용하지 아니하므로, 외국인고용보험은 적용제외대상입니다.
#
# 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0683
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 당연적용 대상 외국인체류자격의 경우 근로를 개시한 날을 취득일로 적용하며, 내국인 근로자와 동일하게 사유가 발생한 날이 속하는 달의 다음달 15일까지 ‘피보험 자격취득신고서’ 제출하여야 합니다.
# ＊ [고용보험법] 시행령 제7조(피보험자격의 취득 또는 상실 신고 등), 시행규칙 제5조(피보험자격의 취득·상실신고 등)
#
# 다만 법무부 출입국관리사무에서 외국인 등록이 늦어져 외국인등록번호가 발번되지 않는 상태에서는 취득,상실신고를 할수 없으므로 외국인등록증이 법정 신고기한 보다 늦게 발급되는 경우, 이후 발급되는 즉시 공단으로 신고하셔야 합니다.
# 일반적으로 외국인 등록번호 지연발급에 따른 지연신고는 과태료 불이행 대상이나 외국인 등록번호 발급이후 기간지연등 사실관계에 따라 업무담당자의 판단을 필요로 하므로 담당자에게 사업장 정보등을 제공하시고 문의하시길 안내드립니다.
#
# ※ 사업장의 정보(사업장관리번호등)가 기재되어있지 않아 부득이 담당자 연락처 확인 가능한 경로 안내드립니다.
# ▶ 근로복지공단 홈페이지 :
# ☞ [공단소개> 조직안내> 지역본부 및 지사 연락처 검색 바로가기 ]
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# 그외 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0684
# contents: 안녕하십니까? 고객님
#
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# 고객님께서 문의하신 “외국인근로자(h2) 퇴직연금 가입”과 관련하여 아래와 같이 알려드립니다.
#
# ｢외국인근로자의 고용 등에 관한 법률｣ 제13조에 의거 출국만기보험 등 외국인전용보험에 의무적으로 가입하여야 하는 외국인 근로자(E-9, H-2)를 제외한 외국인은 퇴직급여제도의 적용대상이 됩니다.
#
# 가입자 등록은 "근로복지공단 퇴직연금(DC) 홈페이지-기업계정으로 로그인-계약정보-가입자관리-가입자 개별등록" 또는 "서식자료실-(별지제3호서식) 퇴직연금 가입대상자 [신규/추가] 등록 신청서"를 작성하여 관할지사로 팩스 접수하여 주시기 바랍니다.
#
# 그 외 기타 궁금한 사항이 있으시면 우리 공단 사업장 관할 지사 또는 근로복지공단 퇴직연금 고객센터(☎1661-0075)로 전화주시면 성심 성의껏 답변해 드리겠습니다.
#
# 오늘도 행복한 하루 보내시길 바랍니다.
#
# * 관할지사조회방법: 근로복지공단 퇴직연금 홈페이지 접속→고객센터→고객지원실→퇴직연금담당자찾기→“지역명”으로 검색→지사팩스번호 및 지사연락처 확인
#
# ※ 인터넷상담은 직접 민원업무 처리를 하지 않으므로 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해바랍니다. 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료 등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0685
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 근로복지공단은 피보험자격 신고(취득, 상실, 일용근로내역 등) 및 고용, 산재보험료 금액에 대해서는 확인 가능하나, 문의하신 피보험자 임금산정기준 및 방법에 관련하여서는 고용노동부에서 업무를 수행하고 있사오니 해당 문의는 번거로우시겠지만 아래의 경로에서 문의하시기를 안내드립니다. 바로 도움을 드리지 못하는 점 너그러운 이해 바랍니다.
#
# ▶ 대표번호 : (국번없이 )1350
# ▶ 홈페이지 : 민원마당(minwon.moel.go.kr) > 민원신청 > 빠른인터넷상담
#
# 사이버상담실은 고객센터에서 답변드리고 있어 제공하신 가장 일반적인 기준 및 규정 등 안내드리고 있으며, 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0686
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인 근로자의 경우 체류자격과 무관하게 산재보험 당연가입대상이며 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어 집니다.
# * F2, F5, F6 : 실업급여 및 고용안정직업능력개발 당연가입
# * H2, E9 : 고용안정직업능력개발 (당연가입), 실업급여(임의가입)
#
# 산재보험은 외국인근로자의 체류자격과 무관하게 산재보험은 당연가입 대상이므로 실제 근로개시일을 취득일로 적용합니다.
# 고용보험은 상기 안내드린 당연적용 대상 외국인체류자격의 경우에만 근로를 개시한 날을 취득일로 적용하며, 고용보험 임의가입의 경우 출입국관리법상 국내취업활동이 가능한 체류자격을 가진 외국인은 본인이 가입을 희망하는 경우에 한하여 적용(임의적용)이 가능하며 가입신청을 한 날의 다음 날이 취득일(※ 소급적용 불가)이 됩니다.
#
# 또한 고용허가제대상 외국인 근로자(E-9, H-2)는 고용허가 기간내에만 고용보험을 적용합니다. 해당 체류코드를 가진 외국인의 경우 취득일(취득)· 근무일(근로내용)· 채용일(가입신청), 근로개시일 또는 사유발생일(=상실일) 등 고용허가 기간내인지 담당자가 확인후 처리 하도록 되어있습니다. 따라서 외국인의 경우 고용보험 취득일 적용은 상기 안내드린 내용에 따라 다르게 적용될수 있습니다.
#
# 사이버상담실은 고객센터에서 답변드리고 있어 가장 일반적인 기준 및 규정 등 안내드리고 있으며, 개별적인 업무에 대한 확인 및 판단을 해드릴 수 없으며 체류자격에 따른 구체적인 판단을 필요로 하는 경우 사업장 관할지사 담당자에게 문의하시길 안내드립니다.
#
# ▶ 근로복지공단 관할지사 담당자 검색 : ☞ [지역본부 및 지사 찾기 바로가기 ]
#
# 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0687
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인근로자의 체류자격과 무관하게 산재보험은 당연가입 대상이므로 산재보험은 외국인등록번호가 나오면 실제 근로개시일을 취득일로 취득신고서를 접수하시면 됩니다. (단, 미성립 사업장인 경우 최초 근로개시일로부터 14일이내 보험관계성립신고서를 먼저 접수해야함)
#
# 외국인 근로자의 경우 체류자격과 무관하게 산재보험 당연가입대상이며 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어 집니다.
# * F2, F5, F6 : 실업급여 및 고용안정직업능력개발 당연가입
# * H2, E9 : 고용안정직업능력개발 (당연가입), 실업급여(임의가입)
#
# 고용보험은 상기 안내드린 당연적용 대상 외국인체류자격의 경우에만 근로를 개시한 날을 취득일로 적용하며, 내국인 근로자와 동일하게 사유가 발생한 날이 속하는 달의 다음달 15일까지 ‘피보험 자격취득신고서’ 제출하여야 합니다. 외국인등록증이 신고기한보다 늦게 발급되는 경우 발급되는 즉시 신고해주시길 안내드립니다.
# 고용보험 임의가입의 경우 출입국관리법상 국내취업활동이 가능한 체류자격을 가진 외국인은 본인이 가입을 희망하는 경우에 한하여 적용(임의적용)이 가능하며 가입신청을 한 날의 다음 날이 취득일(※ 소급적용 불가)이 됩니다. 고용보험 가입을 희망하는 경우 [외국인 고용보험 가입(탈퇴)신청서]+ [근로내용확인신고서] 제출하여 가입하시면 됩니다.
#
# 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 개별사례에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다. 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0688
# contents: 안녕하십니까? 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# 사이버상담은 고객센터에서 답변을 드리고 있으며 민원업무를 직접 처리하지 않는 관계로 개별적인 업무에 대한 판단을 해드릴 수 없어 일반적인 처리기준 및 절차에 대한 답변 가능한 점 양해부탁드립니다.
#
# 문의하신 질문에 답변드립니다.
#
# 불법체류자의 경우 산재요양 승인 기간 중에 한하여 비자코드를 변경할 수 있도록 되어 있습니다.
# 산재요양 승인 확인서를 가지고 출입국관리사무소를 통해 비자코드를 변경 하신 후 계좌 발급이 가능할 것으로 판단되오니 참고하시기 바랍니다.
#
# 다만 고객님의 문의는 정확한 개인정보 등을 필요로 하는 내용으로 일반적인 기준과 처리절차에 대한 안내로 운영되는 사이버상담에서는 보다 상세한 안내가 어려운 점 양해부탁드리며 보다 상세한 사항은 실제 업무를 수행중인 관할지사 담당자에게 문의하여 주시기 바랍니다. 바로 도움을 드리지 못하는 점 너그러운 이해 바랍니다.
#
# - [근로복지공단 지사 연락처 및 팩스번호 찾기]근로복지공단홈페이지 메인화면 공단소개 → 조직안내 → 지역본부 및 지사
#
# 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 사이버상담 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0689
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# ※ 연 구(E-3): 고용보험 임의 가입대상자로 근로자의 선택의 따라 가입탈퇴가 가능합니다.
# 근로자가 퇴사하여 고용보험자격을 상실한 경우 [ 피보험자격상실신고서(상실일 : 이직일의 다음날) ]를 제출하며, 근로자가 근무 중 임의로 탈퇴신청하는 경우 [ 외국인 고용보험 가입탈퇴 신청서 (상실일 : 탈퇴신청한 날의 다음날) ]를 제출하여야 처리 합니다. (※ 소급적용 불가)
#
#  ▶ 온라인 접수
# : 고용산재보험토탈서비스[ https://total.comwel.or.kr ] (사업장으로 로그인)
# • 민원접수/신고 > 자격관리 > 외국인 고용보험 가입(가입탈퇴)신청
#
# ▶ 팩스 서면접수
# • 근로복지공단 사이트 : ☞ [서식자료실 바로가기]
# [ 외국인 고용보험 가입탈퇴 신청서] 서식 다운로드 후 작성 관할지사로 팩스 접수
# • 근로복지공단 관할지사 담당자 검색 (지사 팩스번호 및 연락처 확인 가능)
# : ☞ [지역본부 및 지사 찾기 바로가기 ]
#
# 사이버상담실은 고객센터에서 답변드리고 있어 가장 일반적인 기준 및 규정 등 안내드리고 있으며, 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c068a
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의 내용에 답변드립니다.
#
# 외국인 근로자의 경우 산재보험은 당연가입 대상이나 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어 집니다. H2(방문취업), E9(비전문취업) 체류자격 소지 외국인 근로자의 경우 2021년부터 고용보험 중 고용안정·직업능력보험이 당연적용으로 변경되었으나 사업장의 상시근로자수에 따라 시행시기를 다르게 적용합니다.
# ▶ 고용보험(고용안정·직업능력개발사업) 당연가입 : H2(방문취업), E9(비전문취업)
# - 상시30명 이상 근로자 사용 사업 2021.1.1부터 적용
# - 상시10명 이상 근로자 사용 사업 2022.1.1부터 적용
# - 상시10명 미만 근로자 사용 사업 2023.1.1부터 적용
#
# 이에 따라 고객님 사업장이 10인 미만 사업장이면서 E9 체류자격인 외국인 근로자를 2022년 10월 고용한 경우 [2023년 1월 1일]을 고용보험 자격취득일로 하여 피보험 자격취득신고서를 제출하시면 됩니다.
# ※ F2, F5, F6 : 실업급여·고용안정직업능력 당연가입
#    비전문취업(E-9), 방문취업(H-2) : 고용안정직업능력개발 (당연가입), 실업급여(임의가입)
#
# 제공하신 제한된 정보를 근거로한 가장 일반적인 사항을 안내드린 것으로 개별사안에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다. 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c068b
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 고용보험은 기존 외국인으서 가입한 당시 체류자격을 확인하시어 고용보험이 임의가입 또는 당연가입 이었는지 여부에 따라 신고내용이 달라짐을 안내드립니다.
#
# ▶외국인근로자가 내국인(한국국적)으로 변동되어 당연가입에서 당연가입자로 된 경우
# ☞ 피보험자내용변경신고(성명,주민등록번호)
# ※ 이력을 연결시켜주기 위한 주민등록번호 변경신고만 해주시면 됩니다.
#
# ▶외국인근로자가 내국인(한국국적)으로 변동되어 임의가입에서 당연가입자로 된 경우
# ☞ 근로자 상실신고 → 근로자 취득신고 → 피보험자내용변경신고(성명,주민등록번호)
# ※ 국적 변동으로 임의가입→당연가입으로 적용된다면 임의가입 상실신고 후 취득신고를 진행하고, 이력을 연결시켜주기 위해 이전 외국인등록번호로 가입된 이력을 새로이 생성된 주민등록번호로 변경해야 하므로 피보험자내용변경신고를 해주셔야 합니다.
#
# 1> 온라인 접수
# ▶ 고용산재보험토탈서비스 https://total.comwel.or.kr (사업장으로 로그인)
# •민원접수/신고 > 자격관리 > 근로자 자격상실신고(10502)
# •민원접수/신고 > 자격관리 > 근로자 자격취득신고(10501)
# •민원접수/신고 > 자격관리 > 근로자정보변경신고(10503)
#
# 2> 팩스 서면접수
# ▶ 근로복지공단 사이트 https://www.comwel.or.kr 접속 → 정보공개 > 자료실 > 서식자료
# [피보험자내용변경신고서] 서식 다운로드 후 작성 관할지사로 팩스 접수
# 구비서류: 변경된 외국인근로자의 신분증 사본, 지사에서 필요시 추가서류 요청할 수 있음
# •공단소개 > 조직안내 > 지역본부 및 지사 (지사 팩스번호 및 전화번호 확인 가능)
#
#
# 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 개별사례에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다.
#
# 사이버상담은 고객센터에서 답변을 드리고 있으며 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 확인 및  판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해 부탁드립니다.
#
# 사이버상담실은 고객센터에서 답변드리고 있어 가장 일반적인 기준 및 규정 등 안내드리고 있으며, 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c068c
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# [E-9(비전문취업) = 고용안정직업능력개발 (당연가입), 실업급여(임의가입)]으로 고용허가외국인이 근무를 시작하면 사업장에서는 일반 근로자와 동일한 서류로 취득신고를 접수 해 주시면 고안·직능만 가입이 되며, 그 외국인이 실업급여에 가입하고자 하는경우 별도 [외국인고용보험가입신청서]를 통해 접수 해 주시면 접수한 날의 다음날 부터 적용되고 소급취득은 불가합니다.
# 또한 피보험자에 대한 취득·상실·근로내용확인 등의 신고를 고용보험법 시행령 제7조에 정해진 법정신고기한내에 신고하지 않거나(지연신고 포함) 거짓신고한 경우 피보험자 1명당 1개월에 3만원(최대 100만원을 초과할 수 없음_거짓신고 시 최대 300만원 한도)의 과태료 부과 규정이 있으므로 외국인등록번호를 부여받지 못하는 등의 사유가 발생하여 법정신고기간내에 신고가 어려운 경우 사업장 관할지사 담당자와 상의하여 처리하시길 안내드립니다.
#
# 사업장의 정보가 기재되어있지 않아 부득이 관할지사 담당자 연락처 확인 가능한 경로 안내드립니다.
# ▶ 근로복지공단 관할지사 담당자 검색경로 (근로복지공단 https://www.comwel.or.kr)
# · 공단소개 > 조직안내 > 지역본부 및 지사 (지사 팩스번호 및 연락처 확인 가능)
#
# 사이버상담은 고객센터에서 답변을 드리고 있으며 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다. 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c068d
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의 내용에 답변드립니다.
#
# 2018. 7. 1. 법의 적용 제외 사업으로 규정하고 있던 「산재보험법 시행령」 제2조가 개정·시행되면서 고용·산재보험은 근로자를 사용(고용)하는 모든 사업 또는 사업장에 적용합니다. 다만, 개인이 운영하는(법인이 아닌 자의 사업으로서) 농·임(벌목업 제외)·어업·수렵업의 상시 5명 미만 사업은 산재보험 의무가입대상이 아니며, 고용보험도 개인이 운영하는(법인이 아닌 자의 사업으로서) 농·임·어업의 상시 4명 이하 사업은 의무가입 대상이 아니며 고용·산재보험 가입을 원하는 경우 공단의 승인을 받아 보험에 가입할 수 있습니다. (다만, 고용보험 임의가입 대상인 경우 근로자(적용제외 근로자 제외)의 과반수의 동의를 받아야 함 (「보험료징수법」제5조제2항))
#
# 농업·임업(벌목업제외)·어업 수렵업 중 법인이 아닌 자의 사업의 상시근로자수가 5명 이상 되는 경우 고용·산재보험 당연가입 대상이므로 E-9 비자 소지한 외국인 근로자도 고용·산재보험 모두 취득해야 합니다. (E-9 고용보험은 고용안정·직업능력보험만 적용대상으로 실업급여 가입을 원하는 경우 외국인고용보험가입신청서를 별도로 제출)
#
# 다만 근로복지공단은 고용·산재보험만 소관하므로 건강보험 및 국민연금은 해당기관으로 근로자 가입기준 등 문의하시기를 안내드립니다.
# ▶ 건강보험공단 1577-1000
# ▶ 국민연금공단 (국번없이)1355
#
# 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c068e
# contents: 고객님 안녕하십니까?
# 근로복지공단 고객센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 고객센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의 내용에 답변드립니다.
#
# 고용·산재보험의 보험료 산정기준은 '보수'이며 보수는 소득세법 제20조에 따른 근로소득(봉급, 급료, 보수, 세비, 임금, 상여, 수당과 이와 유사한 성질의 급여)에서 소득세법 제12조 제3호에 따른 비과세 근로소득을 뺀 세금 공제전 금액입니다.
#
# 따라서 일반근로자와 동일하게 비과세 근로소득을 빼고 신고하시면 되오며 다만 외국인이 내국인처럼 분리과세를 선택하지 않고 단일세율 적용하여 연간 근로소득을 국세청에 신고한 경우 이후 국세청 연계정산 상이내역 안내 시 국세청 신고금액과의 차액에 대해 급여대장 등 소득세법상 비과세항목을 판단할 수 있는 증빙서류를 첨부하여 공단에 이의신청서를 제출 하여야합니다.
#
# 제공하신 제한된 정보를 근거로한 가장 일반적인 사항을 안내드린 것으로 개별사안에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다. 기타 궁금한 사항이 있으시면 근로복지공단 고객센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c068f
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◇문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인 근로자의 경우 체류자격과 무관하게 산재보험 당연가입대상이며 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어 집니다.
#
# * F2, F5, F6 : 실업급여·고용안정직업능력 당연가입 대상입니다.
# * 방문취업(H-2) : 고용안정직업능력개발 (당연가입), 실업급여(임의가입)
# 실업급여 고용보험에 가입을 원하는 경우 외국인 고용보험 가입(가입탈퇴 신청서) 와 외국인 등록증 앞·뒷면 사본첨부하여 접수하시면 됩니다. (※ 행정정보동의 체크시 생략 가능하며 지사에서 필요시 추가서류 요청할 수 있음)
# * 일반연수(D-4) : 고용보험 가입대상이 아닙니다.
#
# 사이버상담실은 콜센터에서 답변드리고 있어 가장 일반적인 기준 및 규정 등 안내드리고 있으며, 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0690
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◆문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인근로자의 경우 체류자격과 무관하게 산재보험은 당연가입 대상이므로 그 사유가 발생한 날이 속하는 달의 다음달 15일까지 공단에 취득신고서를 접수하면 됩니다.
# 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어지며 F-4 체류자격의 경우 고용보험 임의가입대상입니다.
#
# 임의가입대상 외국인 근로자가 고용보험 가입을 원하는 경우 「외국인 고용보험 가입·탈퇴 신청서」를 제출하는데 당연가입 대상이 아니므로 소급적용은 불가하고 가입신청서를 제출한 날의 다음날이 취득일이 됩니다.
#
# 외국인 고용허가제 관련업무는 고용노동부 소관업무이므로 번거로우시겠지만 관련 내용은 고용노동부로 문의하시기를 안내드립니다.
# ▶ 전화상담 : 고용노동부 (국번없이)1350
# ▶ 온라인상담 : 고용노동부 홈페이지 https://www.moel.go.kr → 민원 > 민원신청 > 빠른인터넷상담
#
#
# ◆사이버상담은 콜센터에서 답변을 드리고 있으며 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다.
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다. 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0691
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◆문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인 일용근로자의 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어 집니다.
# H2(방문취업), E9(비전문취업) 체류자격 소지 외국인 근로자의 경우 2021년부터 고용보험 중 고용안정·직업능력보험이 당연적용으로 변경되었으나 사업장의 상시근로자수에 따라 시행시기를 다르게 적용합니다.
# ▶ 고용보험(고용안정·직업능력개발사업) 당연가입 : H2(방문취업), E9(비전문취업)
# - 상시30명 이상 근로자 사용 사업 2021.1.1부터 적용
# - 상시10명 이상 근로자 사용 사업 2022.1.1부터 적용
# - 상시10명 미만 근로자 사용 사업 2023.1.1부터 적용
# 따라서 상시근로자 10인미만 사업장도 2023.1.1.부터는 H2, E9 비자 소지 외국인의 고용안정·직업능력보험은 당연가입하므로 취득신고서를 접수(H2, E9 비자 소지 외국인근로자가 실업급여 가입을 원하는 경우 외국인고용보험가입신청서 별도 제출)하고 고용안정·직업능력보험은 사업장에서만 납부하므로 근로자에게 고용보험료를 부과하지 않습니다.
# ※ F2, F5, F6(실업급여·고용안정직업능력 당연가입), H2, E9(고용안정직업능력만 당연가입)를 제외한 체류자격은 고용보험 임의가입 또는 대상아님
#
# - 임의가입대상 : 가입신청을 한 날의 다음 날이 취득일(※ 소급적용 불가)이 됩니다.
# ※ 만약 근로내용확인신고서로 신고한 경우 근로내용확인신고서의 실제 근로한 일자로 피보험자격을 취득한 것으로 봄
#
# 위 내용에 따라 적용되면 근로자의 체류 자격에 따라 법 적용요건 확인이 필요할것으로 판단됩니다.
# 또한 당연가입 체류자격의 외국인의 경우 고용보험 취득신고가 지연되거나 미신고 시 과태료가 부과되며 당연가입이 아닌 체류자격의 외국인 근로자는 가입의 의무가 없습니다.
#
#
# ※ 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 개별사례에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다.
# ◆사이버상담은 콜센터에서 답변을 드리고 있으며 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다.
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0692
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의 내용에 답변드립니다.
#
# 1. 외국인 일용근로자의 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어 집니다. H2(방문취업), E9(비전문취업) 체류자격 소직 외국인 근로자의 경우 2021년부터 고용보험 중 고용안정·직업능력보험이 당연적용으로 변경되었으나 사업장의 상시근로자수에 따라 시행시기를 다르게 적용합니다.
# ▶ 고용보험(고용안정·직업능력개발사업) 당연가입 : H2(방문취업), E9(비전문취업)
# - 상시30명 이상 근로자 사용 사업 2021.1.1부터 적용
# - 상시10명 이상 근로자 사용 사업 2022.1.1부터 적용
# - 상시10명 미만 근로자 사용 사업 2023.1.1부터 적용
# 따라서 상시근로자 10인미만 사업장도 2023.1.1.부터는 H2, E9 비자 소지 외국인의 고용안정·직업능력보험은 당연가입하므로 취득신고서를 접수(H2, E9 비자 소지 외국인근로자가 실업급여 가입을 원하는 경우 외국인고용보험가입신청서 별도 제출)하고 고용안정·직업능력보험은 사업장에서만 납부하므로 근로자에게 고용보험료를 부과하지 않습니다.
# ※ F2, F5, F6(실업급여·고용안정직업능력 당연가입), H2, E9(고용안정직업능력만 당연가입)를 제외한 체류자격은 고용보험 임의가입 또는 대상아님
#
# 2. 당연가입 체류자격의 외국인의 경우 고용보험 취득신고가 지연되거나 미신고 시 과태료가 부과되오며 당연가입이 아닌 체류자격의 외국인 근로자는 가입의 의무가 없습니다.
#
# 고용보험은 실직자에 대한 생계지원 및 적극적인 취업알선을 통한 재취업의 촉진 등을 지원하는 사회보장제도 입니다. 실업급여 등 고용보험혜택은 고용노동부 고용센터에서 수행하고 있으므로 고용보험 혜택에 대하여 보다 더 자세한 상담을 받기 원하시는 경우에는 고용노동부 고객센터(국번없이 1350)으로 문의하시면 안내를 받으실 수 있습니다.
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0693
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◆문의하신 내용에 아래와 같이 답변 드립니다.
#
# 외국인의 체류자격이 G-1 인경우 고용보험은 가입대상이 아닙니다. 고용보험료가 공제 되었다면 사업장으로 확인이 필요할것으로 보여집니다.
#
# 또한 근로복지공단은 고용·산재보험 가입·부과·피보험자 관리 및 산재 보상·요양·재활·의료서비스 업무와 그 외 일부 복지업무를 수행하고 있습니다. 그외 건강보험 연금보험 소득세등. 관련기관으로 공제 대상은 별도로 문의하시셔야 합니다.
# ▶ 건강보험공단 1577-1000
# ▶ 국민연금공단 (국번없이)1355
# ▶ 국세청 : 126
#
#
# ◇사이버상담은 콜센터에서 답변을 드리고 있으며 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다.
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0694
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의 내용에 답변드립니다.
#
# 1. 외국인근로자의 경우 체류자격과 무관하게 산재보험은 당연가입 대상이므로 그 사유가 발생한 날이 속하는 달의 다음달 15일까지 공단에 취득신고서를 접수하면 됩니다. 산재보험 취득신고 접수 방법 안내드립니다.
#
# ▶ 온라인 접수
# 고용산재보험토탈서비스 https://total.comwel.or.kr (사업장으로 로그인)
# · 민원접수/신고 > 자격관리 > 근로자 자격취득신고(10501)
# ▶ 팩스로 서면접수
# 근로복지공단 https://www.comwel.or.kr > 정보공개 > 자료실 > 서식자료
# 서식자료실에서 「고용보험 근로자 피보험자격취득 신고서_산재보험 근로자 자격취득 신고서(2022.12.30.개정))」 서식 다운로드 후 산재보험 작성해서 관할지사로 팩스접수
#
# 2. 고용보험은 체류자격에 따라 당연가입과 임의가입(또는 비대상)으로 나누어지며 F-4 체류자격의 경우 고용보험 임의가입대상입니다.
#
# 임의가입대상 외국인 근로자가 고용보험 가입을 원하는 경우 「외국인 고용보험 가입·탈퇴 신청서」를 제출하는데 당연가입 대상이 아니므로 소급적용은 불가하고 가입신청서를 제출한 날의 다음날이 취득일이 됩니다.
#
# 외국인 고용보험 가입신청 방법 안내드립니다.
#
# ▶ 온라인 접수
# 고용산재보험토탈서비스 https://total.comwel.or.kr (사업장으로 로그인)
# · 민원접수/신고 > 자격관리 > 외국인 고용보험 가입(가입탈퇴)신청
# ▶ 팩스로 서면접수
# 근로복지공단 사이트 https://www.comwel.or.kr → 정보공개 > 자료실 > 서식자료
# 서식자료실에서 「외국인 고용보험 가입, 탈퇴 신청서(2021.7.1.개정)」 서식 다운로드 후 작성해서 관할지사로 팩스접수
# ○ 공통구비서류 : 외국인 등록증 앞·뒷면 사본(※ 행정정보동의 체크시 생략 가능)
# ▶ 관할지사 팩스번호 및 전화번호 확인 경로
# 근로복지공단 사이트 https://www.comwel.or.kr → 공단소개 > 조직안내 > 지역본부 및 지사
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0695
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해 부탁드립니다.
#
# ◆문의하신 내용에 아래와 같이 답변 드립니다.
#
#  체류자격변경으로 실업급여 보험료 부과를 위해서는 근로자상실신고 → 근로자 취득신고 → 피보험자내용변경신고(이력을 연결시켜주기 위해 이전 외국인등록번호로 가입된 이력을 새로이 생성된 주민등록번호로 변경 )를 접수 하면 됩니다.
#  공통구비서류 : 외국인 등록증 앞·뒷면 사본(※ 행정정보동의 체크시 생략 가능) 지사에서 필요시 추가서류 요청할 수 있습니다.
# ▶ 고용산재보험토탈서비스 https://total.comwel.or.kr (사업장으로 로그인)
# · 민원접수/신고 > 자격관리 > 근로자 자격상실신고(10502)
# · 민원접수/신고 > 자격관리 > 근로자 자격취득신고(10501)
# · 민원접수/신고 > 자격관리 > 근로자 정보변경신고(10503)
#
# ▶ 팩스로 서면접수
# 근로복지공단 사이트 https://www.comwel.or.kr 접속 → 정보공개 > 자료실 > 서식자료
# 피보험자격상실신고서 , 피보험자내역취득신고서, 피보험자내역변경신고서를 다운로드 후 작성해서 관할지사로 팩스접수
# · 공단소개 > 조직안내 > 지역본부 및 지사(지사 팩스번호 및 전화번호 확인 가능)
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 항상 건강하고 좋은 일 가득하기를 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0696
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변 드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의내용에 답변 드립니다.
#
# 체류자격 F-2(거주)와 F-5(영주) 모두 고용보험 당연가입 대상이므로 보험 적용 관련 별도의 변경은 불필요하나 체류자격 변경으로 외국인등록번호가 변경됨에따라 근로자의 주민등록번호(외국인등록번호)를 변경해야 하며 신고 방법 안내드립니다.
#
# ▶ 온라인 접수
# 고용산재보험토탈서비스 https://total.comwel.or.kr (사업장으로 로그인)
# · 민원접수/신고 > 자격관리 > 근로자정보변경신고(10503)
# ▶ 팩스로 서면접수
# 근로복지공단 https://www.comwel.or.kr
# · 정보공개 > 자료실 > 서식자료
# 서식자료실에서 「근로자정보변경_피보험자내용변경신고서(2020.12.10)」서식 다운로드 후 작성해서 관할지사로 팩스접수
# ▶ 팩스번호 조회방법
# · 공단소개 > 조직안내 > 지역본부 및 지사
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0697
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변드리고 있어 기준, 원칙, 민원신청 절차 안내 등 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의내용에 답변 드립니다.
#
# 근로복지공단은 고용·산재보험 가입·부과·피보험자관리 및 산재 보상·요양·재활·의료서비스 업무와 그 외 일부 복지업무를 수행하고 있습니다. 외국인근로자 채용 관련 체류자격 H2(방문취업)와 E9(비전문취업)은 고용노동부에서 고용허가제로 운영하고 있으며 그 외 체류자격은 법무부에서 소관하고 있으므로 외국인 근로자의 채용 관련 부분은 각 해당 기관으로 문의하시기를 안내드립니다.
#
# ▶ 고용노동부 (국번없이)1350
# ▶ 고용노동부 홈페이지 https://www.moel.go.kr → 민원 > 민원신청 > 빠른인터넷상담
#
# ▶ 법무부 외국인 종합안내센터 (국번없이)1345
# ▶ 출입국 외국인정책본부 https://www.immigration.go.kr
#
# 참고로 둘 이상의 고용보험 보험관계 성립사업에 동시에 고용되어 있는 근로자는 산재보험은 이중취득 가능하나 고용보험은 하나의 사업에만 고용보험 피보험자격을 취득할 수 있어 이중 취득이 제한되며 고용보험법 시행규칙 제14조에 의거하여 아래 순으로 취득처리가 이루어지고 있습니다.
#
# 1) 상용과 일용이 동시 고용된 경우 : 상용 취득 우선
# 2) 상용과 상용 또는 일용과 일용이 동시 고용된 경우 : 다음의 순으로 취득
# 가. 월평균보수가 많은 사업
# 나. 월 소정근로시간이 많은 사업
# 다. 근로자가 선택한 사업
#
# 따라서 산재보험은 근무하는 모든 사업장에 적용되며 고용보험은 위의 순서에 의해 하나의 사업장으로만 취득되는데 이는 근로자 또는 사업장에서 선택적으로 신고하지않고 근로복지공단에서 직권으로 처리하므로 일용직으로 근무하는 사업장에서도 근로내용확인신고서를 제출해야 합니다. 다만 상용과 일용이 동시에 고용된 경우 상용이 우선이므로 상용직으로 고용보험에 취득되어있다면 일용근로자로 근로내용확인신고서 접수한 내역은 반려처리됩니다. 실시간으로 처리되지않아 일시적으로 이중취득이 되더라도 추후 날짜를 소급해서 정리되며 이중으로 납부했던 보험료는 사업장으로 반환처리 됩니다.
# ※ 단, 외국인 근로자의 경우 체류자격에 따라 고용보험 당연가입대상 여부가 다르며, 임의가입 또는 적용제외대상 체류자격 소지 외국인은 위 내용에 해당사항 없음.
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0698
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변을 드리고 있어 기준·원칙 및 민원신청 절차 등 안내 및 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의내용에 답변 드립니다.
#
# H2, E9 비자를 소지한 외국인 근로자를 사용하는 사업장은 규모에 따라 고용보험(고용안정·직업능력개발) 당연적용대상이 되므로 국내 근로자와 동일하게 근로내용확인신고서를 제출합니다.
# 해당 외국인 근로자는 고용안정·직업능력개발사업에만 적용되므로 근로자 부담분 고용보험료가 부과되지 않습니다. 다만 실업급여는 종전과 동일하게 임의가입으로 실업급여 가입을 원하는 경우 외국인 고용보험 가입신청서와 근로내용확인신고서를 같이 제출하면됩니다.
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0699
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ★ 인터넷상담은 직접 민원업무 처리를 하지 않으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다.
# 개별적인 사안에 대한 보다 자세한 상담은 실제 업무를 수행하고 있는 관할지사 가입지원부 담당자에게 문의하시면 보다 자세한 안내를 받으실 수 있습니다.
#
# 산재보험은 취득이 되어 있지 않다고 해서 산재보상이 되지 않는 것이 아닙니다
# 취업한 사업장이 산재보험 성립이 되어 있다면 소속 근로자의 산재는 보장이 되는것이 걱정하지 않으셔도 됩니다.
#
# 사업장이 전년도 고용보험 피보험자 수가 10인 미만인 사업장의 경우 고용보험(고안‧직능) 당연가입 대상이 되지 않으므로 고객님 사업장이 전년도 고용보험 피보험자 수가 10인 미만사업장이라면 체류자격 E-9 인 외국인 근로자는 고용보험 취득신고 대상이 아닙니다.
#
# 산재보험은 외국인번호가 나오면 실제 취업한 날짜로 취득신고 내시면 되고 (산재보험은 취득신고를 늦게 하더라도 과태료는 없습니다)
# 보험료는 취득신고한 시점이 매달 15일 이후이면 다음달에 소급해서 부과된다고 보시면 되겠습니다.
#
# 상기 내용은 일반적인 내용을 답변 드린 것으로 참고하시고 자세한 내용은 사업장 관할지사 담당자와의 상담을 통하여 처리해 주시기 바랍니다.
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c069a
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변을 드리고 있어 기준·원칙 및 민원신청 절차 등 안내 및 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의내용에 답변 드립니다.
#
# 산재보험은 국내에서 근무하는 근로자에 대해서는 국적과 무관하게 당연가입이나 해외에 파견되는 근로자에 대해서는 의무가입이 아니며, 임의로 가입할 수 있는 특례제도가 있으나 해외 현지에서 직접 채용되거나 해외 사업장에서 임금을 지급하는 경우는 적용대상이 아닙니다.
#
# 국내에서 근무하는 외국인 근로자의 고용보험은 체류자격의 유형에 따라 당연가입 또는 임의가입 대상으로 나누어 지는데 문의하신 근로자의 경우 국내에 체류하지 않아 체류자격이 없으므로 고용보험 가입 대상이 아닐 것으로 사료됩니다.
#
# 위 내용은 제공하신 제한된 정보를 근거로한 일반적인 사항을 안내드린 것으로 개별사례에 대한 구체적인 사실관계에 따라 판단은 달라질 수 있습니다.
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c069b
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버상담은 콜센터에서 답변을 드리고 있어 기준·원칙 및 민원신청 절차 등 안내 및 일반적인 단순문의에 대한 답변만 가능하고 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없는 점 양해부탁드립니다.
#
# 문의내용에 답변 드립니다.
#
# 당연가입대상 사업장이 미가입 또는 체납중인 상태라도 해당 근로자가 당연가입 대상이라면 업무상 재해(업무상 사고, 업무상 질병, 출퇴근 재해)로 인한 요양신청 가능하나 보험가입자가 보험가입의 신고나 보험료의 납부를 태만히 한 기간 중에 발생한 재해에 대하여 보험급여를 지급한 때에는 그 급여액의 전부 또는 일부를 보험가입자로부터 징수할 수 있습니다.
# ① 산재보험 가입신고를 게을리 한 기간 중에 발생한 재해
# · 산재보험 가입신고를 하여야 할 기간이 만료된 날의 다음날부터 가입신고를 한 날까지의 기간 중에 발생한 재해로 지급 결정한 보험급여의 50/100 해당액을 징수하는데 사업주가 가입신고를 게을리한 기간 중에 납부하여야 했던 산재보험료의 5배를 초과할 수 없으며 요양개시일로부터 1년이 되는 날이 속하는 달의 말일까지 기간 중 급여청구사유가 발생한 보험급여에 한해 징수합니다.
# ② 산재보험료 납부를 게을리 한 기간 중에 발생한 재해
# · 월별보험료 또는 개산보험료의 납부기한의 다음 날부터 해당 보험료를 낸 날의 전날까지의 기간 중에 발생한 재해로 재해 발생한 날부터 보험료 납부한 날의 전날까지 기간 중 급여청구사유가 발생한 보험급여의 10/100 해당액을 징수하는데 사업주가 산재보험료의 납부를 게을리한 기간 중에 납부하여야 했던 산재보험료의 5배를 초과할 수 없으며 단, 해당 연도에 내야 할 개산보험료에 대한 보험료 납부액의 비율(분할납부의 경우에는 재해가 발생한 분기까지 내야 할 개산보험료에 대한 보험료 납부액의 비율)이 50/100 이상인 경우는 징수하지 않습니다.
# ③ 가입을 게을리한 기간과 납부를 게을리한 기간 중 발생 재해에 대하여 보험급여액의 징수금을 각각의 요건에 맞게 징수하나, 그 금액은 '납부하여야 하였던 산재보험료의 5배를 초과할 수 없음'으로 상한액을 설정했으며, 장해보상연금 또는 유족보상연금은 최초 급여청구사유가 발생한 날에 장해보상일시금 또는 유족보상일시금이 지급결정된 것으로 보고 징수사유 경합 시에는 보험급여액의 징수비율이 높은 징수금만을 징수합니다.
#
# 「보험료징수법」 제16조의 10제3항부터 제5항에 따른 근로자 고용·종료·전보신고를 거짓으로 신고한 자는 300만원 이하의 과태료(단, 신고를 하지 않은 자의 경우는 100만원 이하)부과, 피보험자에 대한 취득 등의 신고를 고용보험법 시행령 제7조에 정해진 법정신고기한내에 신고하지 않거나(지연신고 포함) 거짓신고한 경우 100만원 한도(거짓신고 3차이상 시 300만원 한도)의 과태료 부과규정이 있습니다.
#
# 다만 위에서 안내드린 내용은 산재보험 미가입 재해에 따른 급여징수금 부과 및 피보험자격 지연신고에 따른 과태료 부과와 관련된 가장 일반적인 규정을 안내드린 것으로 실제 부과는 관할지사 담당자의 사실관계 확인 및 업무판단이 필요한 사항이므로 개별사안에 대한 판단은 관할지사 담당자 통해 확인하시기를 안내드립니다.
#
# 사업장의 정보가 기재되어있지 않아 부득이 관할지사 담당자 연락처 조회 방법 안내드립니다.
# ▶ 관할지사 담당자 조회
# 근로복지공단 https://www.comwel.or.kr → 공단소개 > 조직안내 > 지역본부 및 지사
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c069c
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 인터넷상담은 콜센터에서 답변을 드리고 있어 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다.
#
# 문의내용에 답변 드립니다.
#
# 고용허가제 관련 문의주신 것으로 이해됩니다.
# 근로복지공단은 고용·산재보험 가입·부과·피보험자 관리 및 산재 보상·요양·재활·의료서비스 업무와 그 외 일자리안정자금지원 등의 일부 복지업무를 수행하고있어 정확한 답변이 어렵습니다. 문의하신 내용은 고용노동부 소관 업무이므로 번거로우시겠지만 고용노동부로 문의하시기 바랍니다.
# ▶ 전화상담 : 고용노동부 (국번없이)1350
# ▶ 인터넷상담 : 고용노동부 홈페이지 https://www.moel.go.kr
# 민원 > 민원신청 > 질의민원 또는 빠른인터넷상담
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c069d
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ★ 인터넷상담은 직접 민원업무 처리를 하지 않으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다. 개별적인 사안에 대한 보다 자세한 상담은 실제 업무를 수행하고 있는 관할지사 가입지원부 담당자에게 문의하시면 보다 자세한 안내를 받으실 수 있습니다.
#
# 무급 인턴의 경우 임금을 목적으로 근로를 제공하는 근로자로 볼 수 없어 산재보험 적용 제외대상으로 보는것이 타당하나 실질적인 근로자성 여부는 근로계약서 등을 근거로 종합적으로 검토하여 판단하여야 할 것으로 사료됩니다.
#
# 따라서 고객님이 문의주신 적용 대상여부에 대해서는 관할지사 담당자의 사실 확인 및 업무판단이 필요한 사항으로 사이버 상담실에서 확답드리기 어려운점 양해부탁드리며 보다 구체적인 상담이 필요한 경우에는 관할지사로 문의하여 도움받으시기 바랍니다.
#
# *지사 찾기 : 근로복지공단 홈페이지 (www.comwel.or.kr) → (좌측 상단) 공단소개 → 조직안내 → 지역본부 및 지사 연락처(담당자) 등을 상세하게 검색 가능합니다.
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c069e
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# 사이버 상담실은 일반적인 사항에 대한 답변을 하는 곳으로, 개별사안에 대해서는 세부상담 및 검토가 불가하여 구체적인 답변이 불가한 점 양해 부탁드립니다.
# ▶외국인의 경우, 합법적으로 취업활동이 가능한 체류자격(총 24종) 중 고용보험법상 임의가입이 허용되어 있는 체류자격을 지원합니다.
# * d7∼d9, e1∼e10, f2, f4∼f6, h2
# * 해당 사업장 근무여부 검증이 어려우므로 지원대상 사업장에 사회보험(고용보험·건강보험 등)이 가입된 경우에만 지원
# 고용보험 가입여부에 따라 신청서식이 상이하며, 임의가입 근로자로 고용보험을 가입하지 않았다면 최초 신청시 첨부서류로 근로계약서를 제출, 2회차부터는 고용유지확인서를 매 익월 15일 전까지 제출하여야 합니다.
# 1. 고용보험 적용근로자 신청서식 (상용, 단시간근로자)
#
# [고용보험 기가입자] 2022년 일자리안정자금 지원신청서(일반사업장) + 지원요건확인서
# [고용보험 신규가입자] 피보험자격 취득신고서 + 일자리안정자금 신청 세부내역 + 지원요건확인서
#
# 2. 고용보험 적용제외근로자 신청서식 (외국인, 초단시간 근로자)
# [최초] 일자리안정자금 신청서 + 지원요건확인서, (첨부서류) 근로계약서
# [2회차] 고용유지확인서 (매 익월 15일 전까지 제출)
# ◆ 신청방법
# ① 온라인접수 ⇒ 고용·산재보험 토탈서비스(http://total.kcomwel.or.kr) 사업장회원 로그인 ⇒ 민원접수신고 ⇒ 일자리지원금지원신청
# ② 오프라인접수 ⇒ 일자리안정자금 홈페이지(http://jobfunds.or.kr) ⇒ (상단)신청방법 ⇒ 신청서다운로드 메뉴에서 다운로드 또는 콜센터 통해 팩스/이메일 요청가능
# ⇒ 사업장 관할 근로복지공단 팩스접수 및 우편 또는 방문 접수
# ③ 관할지사 찾기 ⇒ 근로복지공단 홈페이지(www.kcomwel.or.kr) ⇒ (상단)공단소개 ⇒ 조직안내 ⇒ 지역본부 및 지사 메뉴(사업장 관할지사내 경영복지부)
# ※ 온라인 신청 원칙, 단 5인 미만 사업장은 오프라인 신청가능 (신속한 접수 및 처리를 위해 가급적 온라인 신청을 권장)
# ※ 공동대표자가 있는 경우 “공동대표자 개인정보활용동의서”별도 제출필요
# ※ 사업장 업종과 근로자 근무형태 등에 따라 신청서식이 상이하므로 추가적인 내용은 관할지사 경영복지부 또는 복지사업부로 연락 바랍니다.
#
# [ 2022년 일자리안정자금 신청시기: ‘22.1.1.∼’22.6.15. ]
# ☞ 1개월 이상 고용유지 의무 등을 감안할 때, ’22.5.1.까지 노동자를 고용한 사업장에 한해 신청 가능 (’22.5.1.까지 입사한 근로자만 신청 가능)
# ☞ 6월말(5월 근로분)까지만 지원
# [ ‘22년 일자리안정자금 사업주 요건 ]
# ☞ 30인 미만의 근로자를 고용하고 있는 사업주로 최저임금을 준수하고 있는 사업주가 대상
# * 예외
# - 기업규모에 상관없이 지원 : 공동주택 경비·청소원
# - 100인 미만 사업(주)지원 : 장애인활동지원기관
# - 300인 미만 사업(주)지원 : ⑴55세 이상 고령자 ⑵고용위기지역·산업위기대응지역 종사자 ⑶사회적기업·장애인직업재활시설·자활기업 종사자
# - 지원한도: 공동주택 경비·청소원은 한도 제한 없이 지원, 이외 지원대상확대 사업(주)에 대해서는 99인까지 지원
# <지원 제외 사업주> ①고소득 사업주(과세소득 3억원 초과), ②임금체불 명단 공개 중인 사업주, ③국가 및 공공기관, ④국가 등으로부터 인건비 재정지원 받고 있는 사업주, ⑤지원희망월 이전 인위적 고용조정 기업 ⑥최저임금 위반 사업주
# [ ‘22년 일자리안정자금 근로자 요건 ]
# ☞ 고용보험 적용 대상 근로자는 고용보험 가입 신고 필요(적용제외 근로자는 고용보험 가입 여부 불문)
# ☞ ’22년도 월평균보수가 230만원 미만(선원의 경우 284만원 미만)이고, 1개월 이상 고용유지한 근로자(일용근로자는 1개월간 10일 이상 고용)
# <지원 제외 근로자> 전년도 보다 임금수준이 저하된 근로자, 사업주, 사업주의 배우자, 사업주의 직계존비속
# * 신청서에 기재된 정액급여를 소정근로시간으로 나눈 시간급 환산임금이 9,160원 이상이면 최저 임금 준수 인정(시간급으로 판단)
# * 월급근로자 = 월정액급여/월소정근로시간, 주급근로자 = 주정액급여/주소정근로시간, 시간급근로자 = 시간급 임금
# [ 2022년 일자리안정자금 지원금액 기준 - 상용,단시간근로자 ]
# 주 40시간 이상ㅣ3만원
# 주 40시간 미만 근로자ㅣ2.6만원
# 주 30시간 미만 근로자ㅣ2.2만원
# 주 20시간 미만 근로자ㅣ1.8만원
# 주 10시간 미만 근로자ㅣ미지원
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c069f
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# 문의 내용에 답변드립니다.
#
# ▶ 고용산재보험토탈서비스 https://total.comwel.or.kr (사업장으로 로그인)
# 민원접수/신고 > 자격관리 > 근로내용확인신고(10506)
#
# ① 근로내용확인신고 화면에 작성방식 선택에서 엑셀파일 불러오기 선택
# ② 오른쪽 하단에 샘플파일 다운로드(근로자용) 버튼 클릭해 파일 다운로드
# ③ 해당 서식에 외국인의 체류자격코드를 입력할 때 상세코드까지 확인(예: 국민배우자 F-2-1)해 "-"는 제외하고 (예: 국민배우자 F21)입력
# *  다운로드 받으신 전자신고용 엑셀파일에 체류자격 시트 참조하시면 상세코드 확인 가능합니다.
#
# 위의 방법대로 입력 시 엑셀파일로 업로드 신고 가능합니다.
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c06a0
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 인터넷상담은 콜센터에서 답변을 드리고 있어 직접 민원업무 처리를 하지 않으므로 개별적인 업무에 대한 판단을 해드릴 수 없으며 일반적인 단순문의에만 답변 가능한 점 양해부탁드립니다.
#
# 상시근로자수 산정 관련 문의주신 내용에 대한 답변 드립니다.
#
# 1. 「고용보험법 시행령 제12조」제5항1호에 따르면 상시근로자수는 그 사업주가 하는 모든 사업에서 전년도 매월 말일 현재 근로자수의 합계를 전년도의 조업개월수로 나누어 산정한 수로 이때 상시근로자는 일용, 단시간근로자, 외국인근로자, 사학연금 적용자 등 고용형태를 불문하고 사실상 고용된 모든 근로자(고용보험적용제외자도 포함)를 포함하여 산정합니다.
#
# 2. 위에서 안내해드린대로 상시근로자수는 전년도 매월 말일 현재 근로자수의 합계를 전년도의 조업개월수로 나누어 산정된 수로 해당 근로자수가 10인 이상인 경우 H2, E9 비자 소지한 외국인 근로자는 고용보험(고용안정·직업능력) 당연가입 대상이 되며 2022.1.1일 이전 입사자는 2022.1.1일자로 취득, 2022년도 연도 중 입사한 근로자는 근로를 시작한 날로 취득하게 됩니다.
#
# 위의 내용은 참고하시고 「고용보험법」개정에 따른 고용허가 대상 외국인 근로자 고용보험적용을 위한 상시근로자수에 대한 정확한 판단은 관할지사 담당자를 통해 상담 진행 부탁드립니다.
#
# ▶ 근로복지공단 https://www.comwel.or.kr
# 공단소개 > 조직안내 > 지역본부 및 지사
# 해당 메뉴에서 관할지사 전화번호 확인 가능합니다.
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다..
#
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
#
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c06a1
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버 상담실에서는 일반적인 기준에 대해 안내해드리는 기관으로서 직접적인 업무처리를 하지 않음을 양해해 주시기 바랍니다. 또한, 고객님께서 문의하신 내용은 개인정보확인(주민번호, 사업장명 등) 이 필요한 사항으로 콜센터 또는 인터넷 문의는 상담에 다소 제한이 있음을 양지하여 주시기 바랍니다.
# ☞ 고객님께서 문의주신 내용에 대한 답변 드립니다.
#
# 2019년 1월15일 개정된 「고용보험법」에따라 「외국인근로자의 고용 등에 관한 법률」(약칭:외국인고용법)의 적용을 받는 외국인근로자가 2021년 1월 1일부터 단계적으로 고용보험 당연적용 대상으로 변경됨에 따라, 고용허가대상 사업장을 대상으로 안내문이 발송되었습니다.
# 「외국인근로자의 고용 등에 관한 법률」의 적용을 받는 외국인근로자(h2, e9)는 사업장 규모에 따라 단계별로 고용안정 및 직업능력개발사업은 당연적용대상으로 변경되어 해당 외국인근로자의 근로계약 효력발생일이 속한 달의 다음달 15일까지 반드시 고용보험 피보험자격 취득신고 또는 근로내용확인신고(1개월 미만 일용근로자인 경우)를 해야합니다.
# - 상시 30명 이상의 근로자를 사용하는 사업(장): 2021.1.1.
# - 상시 10명 이상에서 30명 미만의 근로자를 사용하는 사업(장): 2022.1.1.
# - 상시 10명 미만의 근로자를 사용하는 사업(장): 2023.1.1.
#
# 따라서 '22.1.1.부터 상시 10인명 이상에서 30명 미만 사업장의 고용허가 대상 체류자격[비전문취업(e-9), 방문취업(h-2)] 외국인근로자는 고안·직능은 당연적용대상으로 변경, 실업급여는 종전과 같이 임의가입대상입니다.
# 고용허가 외국인근로자가 고용보험 미가입상태로 10이상~30인미만 사업장에서 22.1.1.이전부터 근무중일 경우 2022.1.1.로 취득(근로내용확인)신고 제출하여 주시기 바라며 실업급여사업은 종전과 동일하게 임의가입대상이므로, 실업급여까지 적용 받고자 하는 경우 ‘외국인 고용보험 가입신청서’를 제출하여야 합니다.
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c06a2
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버 상담실에서는 일반적인 기준에 대해 안내해드리는 기관으로서 직접적인 업무처리를 하지 않음을 양해해 주시기 바랍니다. 또한, 고객님께서 문의하신 내용은 개인정보확인(주민번호, 사업장명 등) 이 필요한 사항으로 콜센터 또는 인터넷 문의는 상담에 다소 제한이 있음을 양지하여 주시기 바랍니다.
# ☞ 고객님께서 문의주신 내용에 대한 답변 드립니다.
#
# 사업주는 피보험자격 관련 사항(취득·상실·근로내용확인)을 그 사유가 발생한 날이 속하는 달의 다음달 15일까지 공단에 신고하여야 하여야합니다.
# 산재보험의 경우 외국인 등록번호를 부여받지 못한 상황이더라도 미신고로 인한 미가입재해등으로 사업장 소재지 관할지사 담당자와 통화하시어 상담이후 취득에 대한 업무처리 진행하시면 좋을것으로 사료됩니다.
# ※ 지사 찾기 : 근로복지공단홈페이지 → (좌측 상단) 공단소개 → 지역본부 및 지사에서 사업장 관할 지역본부 및 지사 연락처, 팩스번호 등을 상세하게 검색 가능합니다.
#
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c06a3
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버 상담실에서는 일반적인 기준에 대해 안내해드리는 기관으로서 직접적인 업무처리를 하지 않음을 양해해 주시기 바랍니다. 또한, 고객님께서 문의하신 내용에 개인정보확인(주민등록번호, 사업자번호, 사업장명 등) 이 필요한 사항일 경우 인터넷 문의로는 상담에 다소 제한이 있음을 양지하여 주시기 바랍니다.
# ☞ 고객님께서 문의주신 내용에 대한 답변 드립니다.
#
# 1. 고용보험법 제13조 피보험자격의 취득일이란 이 법에 적용되는 사업에 고용된 날에 피보험자격을 취득한다라고 규정되어 있어 새롭게 채용되는 경우 근로계약서상의 근로개시일을 취득일이 됩니다.
# 따라서 사업장과 근로자가 근로계약서상 근로계약시작을 명시하였다면 코로나로 인한 자격격리 2주 후가 아닌 근로계약서상 시작일을 취득일 보는 것이 타당할 것으로 사료됩니다.
# 2. 외국인 등록증, 외국인등록번호가 없어 고용보험 취득신고를 진행할 수 없으나 출입국관리사무소에서 외국인 등록번호를 발급받은 뒤 공단으로 취득신고가 진행되어야 합니다.
# 고객님 사업장이 상시 30명 이상 근로자를 사용하는 사업일 경우 체류자격 E-9은 고용안정직업능력 당연적용대상으로 근로계약 시점부터 소급하여 취득처리되나 실업급여는 임의가입으로 외국인가입신청서를 제출한 날의 다음날이 취득일로 소급적용이 불가합니다.
# 3. 사업주는 피보험자격 관련 사항(취득·상실·근로내용확인)을 그 사유가 발생한 날이 속하는 달의 다음달 15일까지 공단에 신고하여야 하며 산재보험의 경우 외국인 등록번호를 부여받지 못한 상황이더라도 미신고로 인한 미가입재해등으로 사업장 소재지 관할지사 담당자와 통화하시어 상담이후 취득에 대한 업무처리 진행하시면 좋을것으로 사료됩니다.
#
# ※ 고객님의 정보가 별도로 기재되어 있지않아 부득이하게 관할지사 연락처 확인 가능한 홈페이지 경로 안내드립니다.
# * 지사찾기 : 근로복지공단홈페이지(https://www.kcomwel.or.kr) → (좌측 상단) 공단소개 → 지역본부 및 지사에서 사업장 관할 지역본부 및 지사 연락처 등을 상세하게 검색 가능합니다.
#   기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c06a4
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버 상담실에서는 일반적인 기준에 대해 안내해드리는 기관으로서 직접적인 업무처리를 하지 않음을 양해해 주시기 바랍니다.
# ☞ 고객님께서 문의주신 내용에 대한 답변 드립니다.
#
# 2021년 1월1일부터 변경된 고용허가 외국인[비전문취업(E-9), 방문취업(H-2)] 고용보험 적용기준에 대해 아래와 같이 안내드립니다.
# ㅁ 적용시기
# 1. 상시 30명이상의 근로자를 사용하는 사업 또는 사업장 : 2021년 1월1일
# 2. 상시 10명이상 30명 미만의 근로를 사용하는 사업 또는 사업장 : 2022년 1월1일
# 3. 상시 10명 미만의 근로자를 사용하는 사업 또는 사업장 : 2023년 1월1일
#
# ㅁ 적용 기준
# 1.[30인 이상] '21.1.1.부터 고용허가 대상 체류자격[비전문취업(E-9), 방문취업(H-2)] 외국인근로자는 30인 이상 사업장에서 근무할 경우 [고용안정·직업능력개발사업] 당연적용대상이며, 실업급여는 종전과 같이 임의가입대상입니다.
#
# 따라서 고용허가외국인이 근무를 시작하면 사업장에서는 일반 근로자와 동일한 서류로 취득신고를 접수 해 주시면 고안·직능만 가입이 되며, 그 외국인이 실업급여에 가입하고자 하는경우 별도 [외국인고용보험가입신청서]를 통해 접수 해 주시면 접수한 날의 다음날로 가입이 됩니다.
# <예시>
# 30인 이상 사업장에서 21.2.1. 고용한 고용허가 외국인근로자(상용)에 대하여 21.2.15.취득신고 및 가입신청을 각각 한 경우
# => 고안·직능은 21.2.1취득, 실업급여는 신청일 다음날로 21.2.16. 취득
#
# 2.[30인 미만~ 10명이상] 2022년 1월1일 부터 고안·직능은 당연적용대상, 실업급여 임의가입대상 입니다.
# 예를들어 문의하신 경우를 살펴보자면 21년 현재는 종전 규정을 적용받으므로 임의가입신청만 가능하며 가입신청시 신청일의 다음날로 취득됩니다.
#
# 3.[10인 미만] 2023년 1월1일 부터 고안·직능은 당연적용대상, 실업급여 임의가입대상 입니다. 21년 현재는 종전 규정을 적용받으므로 임의가입신청만 가능하며 가입신청시 신청일의 다음날로 취득됩니다.
#
# 기타 궁금한 사항이 있으시면 근로복지공단 콜센터(☎1588-0075)로 전화를 주시면 성심 성의껏 답변해 드리겠습니다.
# 이용해 주셔서 감사합니다. 오늘도 행복한 하루 보내시길 바랍니다.
# ※ 인터넷 질의응답은 법적인 효력을 갖는 결정이나 판단이 아니므로 각종 권리 주장의 근거 또는 증거 자료등으로 사용할 수 없으니 참고하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c06a5
# contents: 고객님 안녕하십니까?
# 근로복지공단 콜센터입니다.
# 먼저 근로복지공단에 대한 고객님의 관심에 깊이 감사드립니다.
#
# ※ 사이버 상담실에서는 일반적인 기준에 대해 안내해드리는 기관으로서 직접적인 업무처리를 하지 않음을 양해해 주시기 바라며 개별건에 대한 확인 및 상담은 관할지사로 연락주시면 자세한 상담이 가능합니다.
# ☞ 고객님께서 문의주신 내용에 대한 답변 드립니다.
#
# 상시근로자수는 전년도 매월 말일 현재 근로자수의 합계를 전년도의 조업개월수로 나누어 산정합니다.
# ※ 상시근로자수 기준은 아래와 같습니다.
# - 해당 보험의 적용대상자만 포함(대표자, 사업주의 동거친족 제외)
# - 고용보험 가입근로자수 산정 시 「출산전·후휴가 및 유산·사산휴가 중인 근로자」, 「육아휴직 및 육아기 근로시간 단축중인 근로자」는 제외
# - 일용근로자는 월 사용된 연인원을 22.3으로 나누어 근로자 수 산정
# - 단시간 근로자는 0.5로 산정
# ...
#
#
# ※ 주의 : 사례에 대한 답변은 법령이나 판례 등의 변경으로 내용이 바뀔 수 있으므로 구체적인 사안에 대해서는 반드시 대한법률구조공단 상담(전화상담은 국번없이 ☎ 132) 등을 통해 다시 한 번 확인하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0970
# contents: [상담내용]
# 헌법제68조 제2항에 의한 헌법소원(헌법재판소법)
# 외국인 귀화허가시 품행단정을 요구하는 것의 위헌 여부
# 외국인으로 한국에 입국하여 일을 하다가 한국 여자와 결혼하여 국적법에 따라 간이귀화를 신청하였습니다. 그런데 과거 불법체류, 업무방해 등으로 벌금형을 받은 적이 있어 품행이 단정하지 아니하다는 이유로 귀화불허처분이 되었습니다. 귀화 가능여부 판단에 불명확한 용어인 품행단정을 요구하는 것은 위헌 아닌가요?
#
# [해결방법]
# 국적법 제5조 제3호에 따르면 외국인이 귀화허가를 받기 위하여 품행이 단정할 것을 요구하고 있습니다. 이와 관련하여 헌법재판소는 “심판대상조항은 이러한 귀화 요건 중 하나로 외국인을 국가공동체의 새로운 구성원으로 받아들이는 데 있어 그가 기존 국가질서 및 사회구성원과 조화를 이룰 수 있는 건전한 인격과 품성을 갖추고 있는지 여부를 판단하기 위한 것으로, 귀화허가 결정에 있어 국가에게 폭넓은 재량권이 인정된다는 점까지를 고려하면, 심판대상조항에서 ‘품행이 단정할 것’과 같이 어느 정도 보편적이고 가치평가적인 개념을 사용하는 것은 불가피한 측면이 있다. (중략) 심판대상조항에서의 ‘품행이 단정할 것’은 ‘귀화신청자를 대한민국의 새로운 구성원으로서 받아들이는 데 지장이 없을 만한 품성과 행실을 갖춘 것’을 의미한다고 해석할 수 있고, 구체적으로 어떠한 경우가 이에 해당하는지는 귀화신청자의 성별, 연령, 직업, 가족, 경력, 전과관계 등 여러 사정을 종합적으로 고려하여 판단될 것이며, 특히 전과관계도 단순히 범죄를 저지른 사실의 유무뿐만이 아니라 범죄의 내용, 처벌의 정도, 범죄 당시 및 범죄 후의 사정, 범죄일로부터 귀화 처분시까지의 기간 등 여러 사정들이 종합적으로 고려될 것이라는 점을 예측할 수 있다.”라고 판시한 바 있습니다.(헌재 2016. 7. 28. 2014헌바421)  따라서 외국인의 귀화에 다소 불명확한 품행이 단정할 것이라는 요건이 있다고 하더라도 귀화허가에 있어서는 국가에 폭넓은 재량권이 인정되는 점, 범죄의 내용 등의 사정이 고려될 것이 예측되는 점 등을 고려해볼 때 명확성의 원칙에 위반되어 위헌이라고 할 수는 없을 것으로 보입니다.
#
#
# ※ 주의 : 사례에 대한 답변은 법령이나 판례 등의 변경으로 내용이 바뀔 수 있으므로 구체적인 사안에 대해서는 반드시 대한법률구조공단 상담(전화상담은 국번없이 ☎ 132) 등을 통해 다시 한 번 확인하시기 바랍니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0971
# contents: [상담내용]
# 퇴직금 지급받을 irp통장 조건을 확실히 알고싶습니다
# 퇴직금 지급시 irp계좌를 개설미적용되는 분을 정확이 알고 싶습니다 55세이 이하라고만 서치되어 있는데 만 55세이하분이 해당되는건지 궁금합니다또한 만 55세이하와 급여 300만원 이하조건의 동시에 해당되야지irp퇴직통장계좌 개설을 안해도 되는지 궁금합니다
#
# [해결방법]
# ‘22. 4. 14.부터는 퇴직금을 근로자가 지정한 개인형퇴직연금제도의 계정 등으로 지급하여야 합니다.- 사용자는 가입자에게 퇴직금 수령을 위한 개인형 퇴직연금제도(IRP)계좌를 개설하도록 안내하고, 기한 내에 퇴직금을 세전 금액으로 지급해야 합니다.  다음의 예외 사유에 해당하는 경우에는 IRP계정 등으로 지급하지 않아도 됩니다.- 55세 이후 퇴직한 경우 - 퇴직급여액이 300만원 이하인 경우- 사망으로 인한 당연퇴직 및 외국인 근로자가 국외 출국한 경우- 타법령에서 퇴직소득을 공제할 수 있도록 한 경우  사용자는 퇴직금의 IRP계정 이전·지급 의무를 성실히 이행하여야 하며, 퇴직금을 근로자의 월급통장 등 일반계좌로 납입하는 것은 허용되지 않음.- 예외 사유에 해당하지 않는 한, 가입자의 신용불량만을 이유로 하여 IRP계정으로 지급하는 것을 거부할 수 없음. 퇴직금 중간정산은 주택구입 등 한정된 사유에 한하여 긴급한 생활자금이 필요한 근로자에게 퇴직금을 미리 정산하여 지급하는 것으로 중간정산 취지상 IRP계정으로 지급하지 않아도 됩니다.위의 예외사유중 한가지라도 충족한다면 IRP계정으로 지급하지 않아도 되며 55세는 만55세를 의미합니다.위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며, 개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다. 기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다. ​
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0972
# contents: [상담내용]
# 무급휴직시 법정공휴일 급여 지급
# 안녕하세요저희 회사에는 외국인근로자분들이 계시는데 개인사유로 배우자 출산이나 고국으로 귀국하는 일이 생겨 근무를 하지 않을때 (무급휴가시) 추석이나 개천절등 법정공휴일는  급여를 지급을 해야하나요?
#
# [해결방법]
# 개인 사유로 인한 무급휴가 중에 포함된 유급주휴일에 대해서는 단체협약이나 취업규칙 등에서 무급휴가기간중 중 임금지급에 관해 이를 규정하거나 그 지급에 관한 당사자 사이의 약정이나 관행이 있다고 인정되지 아니하는 한 임금을 지급할 의무는 없다고 할 것입니다.위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며, 개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다. 기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0973
# contents: [상담내용]
# 직장내 집단 괴롭힘, 갑질에 해당될까요?
# 생산부장, 직장2명이 현장관리자들 모인자리(직,반장실)이라 표현하겠습니다.직,반장실에서 세사람이저 한사람을 거론, 현 파트에서 다른 파트로 빼서 괴롭힌다 라는 내용의 계획을 논의하고, 실제 실행하려 행동에 옮긴 정황이 있고, 저와 부장이 부딪혀 의견을 나누던 중 제가 눈치를 챘고, 옆에 있던 동료도 부장의 말에서 이상한 느낌을 받았다고 했습니다.그리고, 직,반장실에서 세사람이 나누던 얘기를 직접 듣고 3자에게 전달한 사람도 있고, 또 한사람은 저에게 직접 주의, 조심해야 할 거라고 얘기해 주었었습니다.이미, 이 건은 제기되어 그들은 그런일 없고, 저의 추론이라고 하고 있습니다.그동안 담당과장이라고 현장직 열처리 검사파트에있는 저에게 직접 업무지시를 해 왔고, 근무 등록은반장이 해 왔습니다.그러던 중, 23년 3월부터 진행 되어온 고객사로 부터의 라인이관 검사 ISIR을 아무런 교육도, 내용도 모른체.모든 업무 협의는 담당과장이 고객사 직원들과 진행하였으며, 저에게 업무지시는 구두상 지시뿐이었고,지시에 따라 진행했음에도 고객사와 협의가 바뀌거나, 고객사 문제제기시 담당과장의 짜증과 화풀이?저에게 오는듯한 기분에 저 또한 스트레스가 이만저만 아니었습니다.담당과장은 검사일을 하는 저의 장비, 책상 맞은편에 컴퓨터와 책상을 두고 그 자리에서 근무시간 중코를 골며 자고,물론, 자기 자리, 책상은 사무직, 사무실이 있는 곳에있음에도 이곳에 상주하고 있습니다.관리라는 명분으로...때론 저의 뒤에 누군가 갖다놓은 의자하나에감시하듯 자리 잡고, 어느새 코를 골고 잤습니다.때론, 칸막이겸 책장 뒤편에 설치된 타부서 책장 사이에 자리를 깔고 드러누워 자고, 출근해서 오전에 윗분들 얼굴 도장찍고 들어가서 종일 자고 오후4시쯤 또는 중간에 윗분의 전화가 오면 그때야 일어나대응하고, 정시 퇴근 하고.바깥의 현장 사람들 실수하면 안에 들어와 바깥 사람 대상으로 제 앞에서 쌍욕을 하고,물론, 자기 윗사람도 없는 곳에선 쌍욕합니다.저 앞에서 다른사람 쌍욕하면 저 없는 곳에서저 쌍욕할거란거 잘 압니다.이런 담당과장의 일에 어찌할바를 몰라부장에 직접 내용설명을 하고, 담당과장을분리해 달라고 요청하였으나, 주의만 주고,부장 왈 일만 정상적으로 돌아가면 일부 눈감아준다.24년6월5일 아침 조회에서 반장이 저에게 위에서지시 사항이 열처리 검사자는 왜 작업일보를 안적는지, 앞으로는 작업일보를 적어서제출하랍니다.해서 그 위가 누군지 모르겠지만, 기존 담당과장의 지시하에 검사일지를 작성 관리하고 있다.담당이 바뀌는거냐? 담당이 바뀔 때 마다 지시가바뀌는데, 이참에 열처리검사 운영 메뉴얼을만들어서 달라. 하였고,계속 메뉴얼을 얘기하니 만들겠다 해놓고는,제가하는 작업의 사이클 타임을 재겠다는 둥,매번 말이 바뀌었고, 담당과장도 모르고 있다가반장과 제가 계속 대립이 되니 무슨 일인지 물었고과장 또한 검사일지 관리되고 있는데 뭘 말하는거냐라고 반장에게 물었고, 결국 과장과 반장이 둘이 얘기 나눈 후 기존 검사일지를 활용하는 것으로이상하게 변질되었고, 이에 대한 변명 같지도 않은변명이 자꾸 말이 바뀌고 있습니다.8월5일 하계휴가 복귀 후 로작업자 중 1명이 타반파견을 자원해서 빠짐으로 7명이 3명씩 2개조로 돌던 주,야간 근무 편성에서 1명은 노조간부겸 교섭위원 활동으로 빠지고, 1명은 파견.7명으로 주52시간 시행 시 근무조 편성도 작업자들의견 무시하고 일방적 편성, 반강제로 시행하더니,이번 조편성도 일방적으로 이뤄졌다고 로 작업자들은 불만을 토로했습니다.자기들끼리.8월8일 조회 시 기존 검사자가 시편품 빼던것을반장이 뺄거다.공장장 지시로 가공 불량품을 우선적으로 검사품으로 활용하라는 지시에 의한거다.그런데,반장이 가공반 반장과 결탁을 한건지, 직장의 지시였는지 다수의 가공불량품을 연속으로 장입해서검사하라 하고, 심지어 검사도 않고 라인에 투입,가공 하던 품목 중 가공불량품이라고 침탄 후 일주일이 지난 것을 검사하라고 하기에, 이의제기하였고,반장은 뭐가 문제냐? 라고 하여공장장 현장 순회 때 이의제기 해서 정상적으로 진행되고 있습니다.8월13일 화요일. 아침 조회.타반 지원에 자원자 얘기가 있었고,동료 1이 우리반도 외국인 빼고, 정직원이 잔업근무 쇼트작업과 로 작업 지원하면 안되나? 라는 의견을 제시하였고, 반장이 반원 중 지원하시면 외국인 빼고정직원을 잔업 근무 올리겠다 했습니다.그리고, 동료 1일 8월15일 특근 근무에 대해아직 얘기 나온거 없나 라고 물었고 반장은아직 없다 라고 답 하였고,조회는 마무리.동료들이 해산하던 중 제가 개인적으로 반장에게조회 때 얘기한 쇼트 작업과 로 작업 지원의 잔업근무를 내가 자원하겠다.반장이 그럽시다 했고, 제가 그럼 언제부터시행할거냐, 반장이 다음주 월요일 부터 합시다해서 얘기는 끝났습니다.그리고, 8월 16일.금요일 오후4시경. 담당과장과 성적서를 보고 있었고,반장이 있었고, 성적서 얘기 끝난 후 반장이다음주 월요일 부터 시행하려던 잔업얘기, 잔업하려면 쇼트작업과 브러쉬, 방탄, 로 장입 등두루배워야 잔업 투입시킬 수 있다.잔업 하려면 우선 배워라 라고 일방적 말 바꾸기에지원인데, 로 작업자 지원인데, 그것을 배우라는것은 잔업하지 말라는 거네? 내가 내 일을 하면서그 일을 배우라고? 그래야 잔업 할 수 있다고?하지 말라는 말을 정성스레 하네.내가 안할게.라고 끝냈습니다.그리고,8월15일 특근 근무도 16일에 알게 되었는데,같은반 동료들은 출근의사를 물었고, 출근의사를밝혀서 출근했다 했습니다.저에게만 의사를 묻지도 않았고, 저만 배제가되었습니다.일련의 일들에 또 이의제기하니 또 어설픈 얘기만꾸며내듯 하고, 심지어 동료 2에게 배워서 잔업 하겠느냐 라는 의사를 물었고,그 물음에 동료2가 면박을 줬다고합니다.그리고, 조회 때 반장의 어설픈 변명에 조목조목따졌고, 동료 3,4가 제 편을 드는듯 말을 하니짜증까지 냈었고, 제가 자리를 뜨자말자 동료3에게는 왜 저편을 드는거냐고 따졌답니다.동료3은 편드는게 아니라 반장이 말을 바꾼걸바로 얘기하는거다 라고 했답니다.이처럼 저들은 자기 잘못을 반성은 커녕 자꾸제 탓으로 돌리고, 말을 바꾸고, 저를트러블메이커로 만들고 있습니다.일련의 일들을 공장장에 면담을 통해 얘기했더니당사자들에게 직접적으로 저를 향한 작당모의가있었냐고 물었고, 당사자들이 아니라 하니당연히 그들 말만 믿고, 오히려 저를 달랜답시고직장한테 얘기해서 일좀 시켜줘라 할테니맘풀고 일하자, 다른 반으로 이동은 어떠냐라는 식으로 저를 잔업못해서 안달난트러블메이커로 느끼게 하네요.그리고, 9월5일. 오후 2시30분경.반장이 찾아와 공장장이 면담해보라 해서왔다기에 같이 앉아서 얘기를 했다.예상대로 저는 잔업 못해 안달난 그런사람이된 느낌을 받았고,내가 일하는 여기 나는 검사자냐 작업자냐물었더니 검사작업자 라 하기에 웃었습니다.반장은 저보고 말꼬리 잡고 말에 따라 일 안할려는거 아니냐고 했습니다.또, 제게 잔업 의사를 물었고, 또, 배워야 잔업 할수 있다기에 안배워도 된다해도 안한다 했고,낮 말은 새가 듣고, 밤 말은 쥐가 듣는다고 말해줬습니다.그리고,반장은 올해 반에 정년자가 있는데,그분 정년퇴직하면 정직원 충원 안해줄거고,자체수급해야 될건데, 형님도 이 자리에 계속있는다 생각말고 지금 일 하면서 오후에 나와서그일 배우세요. 담당 과장하고 얘기 끝냈습니다.라고 협박으로 느끼게 했습니다.10월14일.생산부장이 반장을 통해 ISIR 성적서를 요청했습니다.하지만, 그 품목은 지난주 담당과장이 보류 지시한 품목이었기에 과장과 통화하라 했는데,몸살로 출근을 안했다며 전화해도 안받을거라며머뭇거렸고, 재차 전화하라 하니 전화는 하는데전화기에서 들리는 목소리는 부장의 목소리였으며, 부장의 지시 내용은 그 품번으로 ISIR성적서가 제출 되었는지, 5월에 제출된 성적서 내용 이력이 있다 하니 10월 10일자로 날짜만 바꿔서출력, 제출토록 하라는 내용이었습니다.저는 조작을 지시하는거냐?담당과장이 알고 있느냐. 통화해보라 했고,그제서야 반장이 과장과 통화하고, 과장도날짜만 바꿔줘라 한다기에, 조작하라는 건데,부당 업무 지시같다 하다보니 점심시간이 되어반장이 점심시간 이후 오겠다 했습니다.점심시간에 반장에게 톡으로 위원장과도 의논해보고 고민할 시간이 필요하다는 내용을 ...
#
# [해결방법]
# 근로기준법 제76조의2에 따른 직장 내 괴롭힘은 ①직장에서의 지위 또는 관계 등의 우위를 이용할 것, ②업무상 적정범위를 넘을 것, ③신체적,정신적인 고통을 주거나 근무환경을 악화시키는 행위일 것 등을 요건으로 하고 있습니다. 이때 괴롭힘에 해당하는 업무상 적정범위를 넘는 행위는 ⅰ) 그 행위가 사회 통념에 비추어 볼 때 업무상 필요성이 인정되지 않거나, ⅱ) 업무상 필요성은 인정되더라도 그 행위의 양태가 사회 통념에 비추어 볼 때 상당하지 않다고 인정되는 행위입니다. 직장내 괴롭힘에 해당하는지 여부는 사실관계 조사를 통한 판단이 필요하므로 인터넷상담만으로 해당여부 답변 드릴 수없음을 양해부탁드리며, 판단을 받고자 하는 경우라면 노동지청으로 진정을 제기하여 도움을 받으시기 바랍니다. 한편, 피해자,근로자, 그 밖에 직장내괴롭힘 사실을 알고 있는 제3자도 사업장 소재지 관할노동지청에 진정제기 할 수 있습니다.- 이때 신고대상 행위는 직장내 괴롭힘 발생사실 조사 피해자 보호 등을 포함한 조치의무 불이행, 신고를 이유로 한 불리한 처우 등 직장내 괴롭힘 관련사항입니다.※ 진정서 제출 방법(고용노동청에 방문 신청하거나 인터넷으로 접수) ① 사업장 관할 지방고용노동청에 방문하여 신고 <고용노동부 홈페이지(www.moel.go.kr) → 상단의 ‘기관소개’ 중 ‘찾아오시는 길’ 선택 → 좌측메뉴 ‘조직안내’ 중 ‘소속기관’ 참조> ② 인터넷을 통한 진정 제기 <고용노동부 홈페이지(www.moel.go.kr) → 민원신청 클릭 → 온라인민원신청→ 진정서검색위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며, 개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다. 기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0974
# contents: [상담내용]
# 해외거주 외국직원과 계약서를 적을때 국내법이 적용되나요
# 화상영어 업체를 준비하고 있습니다.해외(ex.태국)에 거주하는 외국인(ex.미국인)과 노동계약서를 적을 때, 어디 나라 노동법을 적용해야하나요?프리랜서로 고용할 것입니다.추후에 혹시 모를 임급 지급 이라던가의 노동법 관련 문제가 생겼을 때, 법적인 문제를 겪고 싶지 않아서 여쭤봅니다.감사합니다.
#
# [해결방법]
#  외국적 요소가 있는 근로계약관계에서 근로계약 당사자가 어느 나라의 법을 적용받는지에 대해 판단하기 위해서는 ｢국제사법｣에 따라 명시적‧묵시적으로 선택한 준거법이 있는지 여부와 ‘근로자가 일상적으로 노무를 제공하는 국가’에 대한 판단이 필요합니다.다만, 묵시적 준거법 선택여부와 준거법을 선택하지 않은 경우 등을 현실적으로 구별하기 어렵고, 판례에서도 개별 사안마다 구체적 사정을 살펴 판시하고 있는 점 등을 고려할 때,- ‘묵시적 준거법 선택 여부’ 및 ‘일상적 노무 제공 국가’에 대한 판단시▴전체 근로계약기간 중 해외 근무기간,▴근무장소 및 국내복귀예정 여부(한시적으로 해외에 파견한 경우인지 등),▴근로계약 체결 장소, ▴근로시간 등 노무지휘 및 임금 지급의 주체,▴노무 제공의 실질적인 수령자,▴법 적용에 관한 근로자의 기대‧인식 정도 등을 종합적으로 고려하여 근로기준법 적용 여부를 판단해야 합니다.○ 이에 따라 상기 기준을 종합적으로 고려하였을 때,- 우리나라 기업이 소속 근로자를 한시적으로 해외 사무소 등에 파견한 경우에는 묵시적으로 근로기준법을 선택하였거나 일상적 노무제공 국가를 우리나라로 볼 소지가 크므로 근로기준법이 적용된다고 봄이 타당할 것이며,- 반면에 우리나라 기업이 해외 사무소 등에서 현지 근로자를 채용한 경우에는 명시적으로 근로기준법을 준거법으로 선택하지 않은 이상 해외 현지 국가의 법이 적용된다고 볼 것입니다.다만 귀하의 질의상 프리랜서로 계약을 체결한다면, 프리랜서인 경우 개인으로 사업장과 계약하여 사용자와 근로자 관계가 아닐 경우에 근로기준법상의 근로자가 아니므로 근로기준법상 법 규정을 적용 받는 대상이 아닙니다.위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며, 개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다. 기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다. ​​
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0979
# contents: [상담내용]
# 고용보험 미적용자 출산급여 질문
# 21년 10월-23년2월 대학교 연구소 근무23년 2월말 계약종료로 퇴사(저는 계속 일할 의향이 있었지만 육아휴직+업무강도 문제로 회사측에서 계약 연장하지 않았음)6개월간 실업급여 받음(계속 일하고자하는 의지가 있었기때문에 임신과 별개로 실업급여 신청하였음)23년 6월중순 출산23년 10월부터 현재까지 남편이 대표로 있는 법인회사에 연구원으로 재직중그러던중 지인한테 고용보험 미가입자 출산급여라는걸 듣게되서 자격요건을 보던중 유형1이 해당되는것처럼 이해가 돼서 신청해보려는데 위같은 상황에서 23년 2월 퇴사한 회사에서 받지 못한 육아휴직에 대한 (실업급여를 받아서 찜찜..) 고용보험 미가입자 출산급여를 신청할수 있나요?두루뭉실한 답변 거절하구요정확한 근거로 답변한것만 채택할게요
#
# [해결방법]
# 안녕하세요? 네이버 지식인 파트너 고용노동부 입니다. ​출산급여는 재직자 급부사항으로 현재 근로하고 있는 중에 출산시 출산급여를 받을수 있즞 자격요건인 고용보험가입요건을 충족하지 못하고 있는 경우 미적용자 출산급여 제도를 적용 받을수 있는 것으로 아래 내용을 참고하여 주시기 바라며, 대표이사의 동거가족은  고용보험에 가입되지 않는 적용제외자로  고용보험미적용자 출산급여 적용을 받기 어려울 것으로 사료됩니다.​◆ 지원 대상○ 소득활동을 하지만 고용보험의 출산전후휴가 급여를 지원받지 못하는 출산 여성- 소득수준에 대한 제한(상한 및 하한)은 두지 않음- 외국인 제외(단, 결혼이민여성은 포함), 유산·사산 포함(모자보건법 제14조에 따른 인공임신중절 포함)◆ 신청방법 및 신청자○ 출산여성 본인(대리신청 가능)○ 거주지 또는 소속사업장 소재지 관할 고용센터 방문 또는 우편(신청인이 선택 가능),고용보험 홈페이지 온라인 (www.ei.go.kr) 신청 가능◆ 신청시기○ 출산일부터 신청 가능하며, 출산일로부터 1년 이내 신청 ,신청기간 내 1회 신청◆ 지원 수준○ 지원기간: 3개월○ 지급금액: 월 50만원씩○ 지급결정: 신청 접수 후 14일 이내 지급(부지급)결정 및 통지◆ 구비서류- 출산급여 신청서- 소득활동 증빙자료(건강보험자격득실확인서, 부가가치세면세사업자 수입금액증명, 기타 소득활동 및 소득발생 입증자료)- (적용제외사업, 미성립사업장의 경우) 사업주 확인서※ 필요할 경우 추가 서류 별도로 요청할 수 있음◆ 지원 대상 < 근로자 유형>ㅇ (1유형) 고용보험 피보험자로서 180일 수급요건 미충족자ㅇ (2유형) 고용보험법상 적용제외 사업의 근로자 및 적용제외자(간헐적 소득활동)ㅇ (3유형) 고용보험 미성립 사업장의 미가입 근로자(*고용보험 성립 사업장의 미가입근로자는 지원 제외)
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c0984
# contents: [상담내용]
# 내일배움카드 직업훈련 신청관련 질문!!
# 제가 주 15시간 미만으로 편의점에서 알바하는데.. (고용보험도 들어주신다고 말씀하셨어요!!)이럼 내일배움카드 사용해서 직업훈련 수강신청할 때, 실업자로 신청하나요 아님 재직자로 신청하나요??
#
# [해결방법]
# 답변드립니다​알바처에서 고용보험 가입해주면 재직자로 내일배움카드 발급신청해야 합니다
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c098c
# contents: [상담내용]
# 실업급여 조기재취업수당 신청 관련 질문
# 실업급여 수급중에 취업했을경우에 대해 질문합니당!질문1. 소정급여일수 1/2시점 당일에 입사해도 조기재취업수당 신청가능한가요?질문2. 다가오는 실업인정일에 취업신고를해서 취업 직전까지 실업급여를 받는건가요?질문3. 취업한 사업장에 12개월 이상 근무 후에 조기재취업수당을 신청하는건가요? 조기재취업수당은 취업하고나서 1년뒤에나 신청할 수 있는거죠?질문4. 실업급여 수급중에 취업한 회사를 어떻게 입사하게됐는지도 증빙해야하나요? 전전에 다니던 회사인데 갑작스런 입사권유로 취직하게되면 조기재취업수당 신청이 불가능한가요?정확한 답변 부탁드립니당
#
# [해결방법]
# 신청이 가능한걸로 확인됩니다
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c09a0
# contents: [상담내용]
# 외국인 퇴직연금 계좌 개설
# 외국인(f6비자) 인데 퇴사할때 은행에서 퇴직연금 계좌 만들수 있어요?
#
# [해결방법]
# ​1. 외국인근로자의 고용등에 관한 법률제13조제1항제2항에 따라 외국인 근로자를 고용한 사용자는 외국인근로자의 출국 등에 따른 퇴직금 지급을 위하여 출국만기보험에 가입하고 매월 보험료를 납무하여야 하며, 사용자가 출국만기보험에 가입한 경우 퇴직금 제도를 설정한 것으로 보며- 다만 출국만기보험금액이 법정 퇴직금보다 적을 경우에는 그 차액만큼 사업주가 지급하도록 규정하고 있습니다.​2. 사용자가 출국만기보험에서 부족한 퇴직급여(법정퇴직금보다 적은 경우 그 차액)를 충당지급하기 위하여 외국인 근로자를 퇴직연금제도에 가입하는 것이라면 외국인근로자의 고용에 관한 법률제13조에 따른 출국만기보험 의무가입기간과 퇴직연금가입기간이 중복되므로 허용되지 않음을 안내해드립니다.​위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며, 개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다. 기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c09a2
# contents: [상담내용]
# 실업급여 받을수 있나요?
# 회사 퇴직하는데(퇴직사유 우울증)제가 먼저 그만둔다고 말했습니다(사직서 미제출)회사에서 아무 말 없길래 다시 다닌다고 했는데회사에서 그만두라고 합니다회사에서는 인원 충원계획이고요실업급여 달라고 하니까 외국인 연장 안됀다고 거절 하는데실업급여 받을수 있나요?(사직서 미제출)
#
# [해결방법]
# ​​실업급여는 고용보험 피보험자인 근로자가 ①고용보험 적용사업장에서 수급자격과 관련하여 이직일 이전 18개월간 고용보험 피보험단위기간이 180일 이상이고 ②근로의 의사와 능력을 가지고 있으면서 ③자발적 이직이 아닌 계약기간 만료, 권고사직, 해고, 폐업 등 부득이한 사유로 이직(개인사유로 퇴직하였을 경우 고용보험법 시행규칙 제101조 제2항 별표2에서 정하고 있는 정당한 퇴직사유로 인정받는 경우에 한함)하였고 ④재취업을 위해 적극적으로 노력하였음에도 실업일 경우 실업급여 수급자격을 인정받을 수 있습니다.​귀 질의내용만으로 구체적인 사실관계 확인은 어려우나, 사용자에게 먼저 사직의 의사를 통고*한 자진퇴사의 경우 고용보험법 별표2의 사유가 아닌한 실업급여 수급은 불가합니다. * 의사의 통고는 구두로도 가능한 바 반드시 서면으로 이루어 질 필요는 없으며, 통고가 상대방에게 도달한 이후에는 상대방의 동의 없이 철회는 물가합니다.​실제 실업급여 수급자격에 대한 판단 주소지 관할 고용센터에서 이루어지는 점 참고바랍니다.​ 위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며,개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다.기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c09a3
# contents: [상담내용]
# 자발적 퇴사 실업급여
# 안녕하세여  이번에 자발적 퇴사를 하게 됬습니다.그런데 연장근로 주 52시간 초과시 실업급여신청이 가능하다고 하여 문의글 올립니다.약 2년 6개월 일하면서 평일 3~4회 연장글로(일12시간 근무) 및 토or일 1회 근무를 하였습니다.증거는 카톡 대화 내용 ? 정도 구요.이런 경우에도 실업급여 신청이 가능할까요 ? 자발적 퇴사입니다.*한국인 5명 외국인 8명 일하는 소기업 입니다.
#
# [해결방법]
# ​근로기준법 제53조에 따른 연장근로의 제한을 위반하여 주당 근로시간이 52시간 이상인 경우가 이직 전 1년 이내에 2개월(9주)이상 계속된 경우 정당한 이직사유로 인정됩니다. - 1년 이내에 2개월(9주) 동안 주당 근로시간이 52시간을 초과한 경우란 연장근로시간이 12시간 이하인 주가 있더라도 2개월간 평균하여 주당 연장근로시간이 12시간을 초과한 경우를 말하며, 입사 당시부터 계속된 경우라도 이직일 기준 1년 이내 2개월 이상만 발생한 경우 해당(연속하여 9주를 의미)하게 됩니다. ​실제 귀하의 실업급여 수급자격에 대한 확인은 거주지 관할 고용센터에서 이루어지므로 관할 고용센터로 문의하여 도움 받아 보시기 바랍니다. 위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며,개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다.기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다.
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c09a4
# contents: [상담내용]
# 외국인 친구...
# 외국인 친구가 유학비자로 들어와서 지금 알바를 했는데 알바비를 못받고 사장이 실수 많이해서 안주고 외국인 이여서 사람들이 안 와서 안 주고 완전 협박을 했습니다. 도와주세요. 돈을 지급을 안 해 준다고 합니다. 그리고 전화까지 와서 욕을 했습니다. 어떻게 해야되나요. 도와주세요. 제발 도와주세요.
#
# [해결방법]
# ​귀하가 퇴사 후 14일 이내 임금이 청산되지 않을 경우 관할노동청 또는 국민신문고(www.epeople.go.kr)로 진정을 제기하여 구제가 가능합니다.※ 진정 제기 방법 ① 사업장 관할 지방고용노동청에 방문하여 신고하거나 ② 인터넷을 통한 진정 제기 <고용노동부 홈페이지(www.moel.go.kr)→ 왼쪽상단의 민원마당 → 민원신청 → 임금체불 등 진정신고서 → 회원 가입 후 작성하시거나 공인인증서로 로그인 후 신청> ​진정 신청 시 관할노동청을 방문하셔서 신청하셔도 되고, 국민신문고를 통해 체불임금 신고를 하게 되면 관할노동청으로 민원이 배정되어 사건 조사가 진행될 것입니다. 별도 빠르게 도움이 필요한 경우에는 관할노동청 고객지원실로 유선연락하여 동 사안에 대해 문의하거나, 방문 후 면담하면 사업주 연락을 통해 체불내역을 확인 후 청산을 요청할 수 있으니 참고바랍니다.  ​위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며,개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다.기타 궁금한 사항은 고객상담센터(1350)에 문의하시기 바랍니다. 감사합니다.​
# --------------------------------------------------
# ID: 689b3a86ffd306c1cd3c09a5
# contents: [상담내용]
# 외국인 고용시
# 근무하던 외국인 직원이 취업비자를 갱신하기 위하여 퇴사 한 후 본국으로 돌아갔고,한 달이 지난 후 다시 취업비자를 갱신하여 입국하였습니다. 저희는 그 사람을 다시 고용할 의사가 있으나 외국인 등록증발급이 행정절차상 계속 늦어지고 있다고 합니다. 취업비자는 있는데 외국인 등록증이 발급되지 않은 상태에서 근무하는 것은 불법인가요?
#
# [해결방법]
# ​귀하의 질의만으로는 외국인 근로자의 비자코드(노동부는 E9,H2근로자만 관리 대상), 귀 사업장의 외국인고용 허가여부 등을 알 수 없으나  상기 코드의 비자대상이라 하여도 노동부에서 고용허가가 되지 않을 상황에서 근로자를 고용한 경우에는 불법이 될 수 있습니다. - 또한, E9 근로자의 경우 외국인 지정 알선이 안되니 유념하시기 바랍니다. ​위 답변은 당시의 상황에 따른 것이며 법령 개정 등에 따라 변경될 수 있으며, 개인의 구체적인 사실에 따라 법규정해석 등에 이견이 있을 수 있습니다.기타 궁금한 사항은 사업장 관할 고용센터 외국인 고용관리팀에 문의하시기 바랍니다. 감사합니다.
# --------------------------------------------------
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 검색

# %%
# 사용 예시
search_results = search_documents_by_text("상담 내용 작성 후 경기지방노동위원회에 부당해고 구제 신청서", collection)
for doc in search_results:  # 상위 3개만 출력
    print(f"ID: {doc.get('_id', 'N/A')}")
    print(f"Text: {doc.get('text', 'N/A')}")  # 첫 100자만 출력
    print("-" * 50)
